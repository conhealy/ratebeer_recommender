# %%
import numpy as np
import pandas as pd
from surprise import SVD
from surprise import Dataset
from surprise import evaluate, print_perf, Reader, dump
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from xgboost import XGBClassifier
import os
import pickle

# %%
df1 = pd.read_pickle('./df_final1.pkl')
df2 = pd.read_pickle('./df_final2.pkl')
df=pd.concat([df1,df2])

# %% [markdown]
# ### Try a few different models

# %%
print(df.columns.values)
# Out:
# ['abv' 'abv_listed' 'beerID' 'beer_name' 'beer_style' 'brewerID'
#  'review_overall' 'reviewer_username' 'testData' 'text_lookup'
#  'vader_neg_avgVaderNeg' 'vader_neg_medianVaderNeg' 'vader_neg_maxVaderNeg'
#  'vader_neg_minVaderNeg' 'vader_neg_vaderNegRange' 'month_number_of_months'
#  'month_most_common_month' 'text_lookup_text_list'
#  'abv_listed_num_abv_listed' 'brewerID_num_brewers'
#  'weekday_central_most_common_weekday' 'weekday_central_number_of_weekdays'
#  'review_overall_avgOverallScore' 'review_overall_maxOverallScore'
#  'review_overall_medianOverallScore' 'review_overall_overallScoreRange'
#  'review_overall_minOverallScore' 'beerID_beerID_count'
#  'review_palate_avgPalateScore' 'review_palate_medianPalateScore'
#  'review_palate_minPalateScore' 'review_palate_palateScoreRange'
#  'review_palate_maxPalateScore' 'time_from_beginning_TimestampRange'
#  'time_from_beginning_medianTimestamp' 'time_from_beginning_avgTimestamp'
#  'time_from_beginning_maxTimestamp' 'time_from_beginning_minTimestamp'
#  'review_appearance_avgAppearanceScore'
#  'review_appearance_minAppearanceScore'
#  'review_appearance_maxAppearanceScore'
#  'review_appearance_appearanceScoreRange'
#  'review_appearance_medianAppearanceScore' 'review_taste_maxTasteScore'
#  'review_taste_avgTasteScore' 'review_taste_medianTasteScore'
#  'review_taste_minTasteScore' 'review_taste_tasteScoreRange'
#  'vader_neu_vaderNeuRange' 'vader_neu_avgVaderNeu'
#  'vader_neu_medianVaderNeu' 'vader_neu_maxVaderNeu' 'vader_neu_minVaderNeu'
#  'review_aroma_aromaScoreRange' 'review_aroma_medianAromaScore'
#  'review_aroma_avgAromaScore' 'review_aroma_minAromaScore'
#  'review_aroma_maxAromaScore' 'weekend_review_num_weekend_reviews'
#  'abv_avgABV' 'abv_minABV' 'abv_ABVrange' 'abv_maxABV' 'abv_medianABV'
#  'distance_from_july_monthsFromJulyRange'
#  'distance_from_july_avgMonthsFromJuly'
#  'distance_from_july_minMonthsFromJuly'
#  'distance_from_july_maxMonthsFromJuly'
#  'distance_from_july_medianMonthsFromJuly' 'beer_style_numBeerStyles'
#  'vader_pos_minVaderPos' 'vader_pos_avgVaderPos' 'vader_pos_vaderPosRange'
#  'vader_pos_maxVaderPos' 'vader_pos_medianVaderPos' 'beer_variety_index'
#  'beerStyle_variety_index' 'brewer_variety_index' 'rate_of_posting'
#  'weekday_variety_index' 'month_variety_index' 'weekend_review_ratio'
#  'vader_neg_avgVaderNeg_prodAgg' 'vader_neg_medianVaderNeg_prodAgg'
#  'vader_neg_maxVaderNeg_prodAgg' 'vader_neg_minVaderNeg_prodAgg'
#  'vader_neg_vaderNegRange_prodAgg' 'month_number_of_months_prodAgg'
#  'month_most_common_month_prodAgg' 'text_lookup_text_list_prodAgg'
#  'abv_listed_num_abv_listed_prodAgg' 'review_aroma_aromaScoreRange_prodAgg'
#  'review_aroma_medianAromaScore_prodAgg'
#  'review_aroma_avgAromaScore_prodAgg' 'review_aroma_minAromaScore_prodAgg'
#  'review_aroma_maxAromaScore_prodAgg'
#  'weekday_central_most_common_weekday_prodAgg'
#  'weekday_central_number_of_weekdays_prodAgg'
#  'review_overall_avgOverallScore_prodAgg'
#  'review_overall_maxOverallScore_prodAgg'
#  'review_overall_medianOverallScore_prodAgg'
#  'review_overall_overallScoreRange_prodAgg'
#  'review_overall_minOverallScore_prodAgg' 'vader_neu_vaderNeuRange_prodAgg'
#  'vader_neu_avgVaderNeu_prodAgg' 'vader_neu_medianVaderNeu_prodAgg'
#  'vader_neu_maxVaderNeu_prodAgg' 'vader_neu_minVaderNeu_prodAgg'
#  'vader_pos_minVaderPos_prodAgg' 'vader_pos_avgVaderPos_prodAgg'
#  'vader_pos_vaderPosRange_prodAgg' 'vader_pos_maxVaderPos_prodAgg'
#  'vader_pos_medianVaderPos_prodAgg' 'beer_style_numBeerStyles_prodAgg'
#  'time_from_beginning_TimestampRange_prodAgg'
#  'time_from_beginning_medianTimestamp_prodAgg'
#  'time_from_beginning_avgTimestamp_prodAgg'
#  'time_from_beginning_maxTimestamp_prodAgg'
#  'time_from_beginning_minTimestamp_prodAgg'
#  'review_appearance_avgAppearanceScore_prodAgg'
#  'review_appearance_minAppearanceScore_prodAgg'
#  'review_appearance_maxAppearanceScore_prodAgg'
#  'review_appearance_appearanceScoreRange_prodAgg'
#  'review_appearance_medianAppearanceScore_prodAgg'
#  'review_palate_avgPalateScore_prodAgg'
#  'review_palate_medianPalateScore_prodAgg'
#  'review_palate_minPalateScore_prodAgg'
#  'review_palate_palateScoreRange_prodAgg'
#  'review_palate_maxPalateScore_prodAgg'
#  'review_taste_maxTasteScore_prodAgg' 'review_taste_avgTasteScore_prodAgg'
#  'review_taste_medianTasteScore_prodAgg'
#  'review_taste_minTasteScore_prodAgg'
#  'review_taste_tasteScoreRange_prodAgg'
#  'weekend_review_num_weekend_reviews_prodAgg' 'abv_avgABV_prodAgg'
#  'abv_minABV_prodAgg' 'abv_ABVrange_prodAgg' 'abv_maxABV_prodAgg'
#  'abv_medianABV_prodAgg' 'distance_from_july_monthsFromJulyRange_prodAgg'
#  'distance_from_july_avgMonthsFromJuly_prodAgg'
#  'distance_from_july_minMonthsFromJuly_prodAgg'
#  'distance_from_july_maxMonthsFromJuly_prodAgg'
#  'distance_from_july_medianMonthsFromJuly_prodAgg'
#  'reviewer_username_user_count' 'rate_of_posting_prodAgg'
#  'weekend_review_ratio_prodAgg' 'aromaSVD' 'appearanaceSVD' 'palateSVD'
#  'tasteSVD' 'overallSVD']

# %%
df.head()
# Out:
#    abv  abv_listed  beerID               beer_name beer_style  brewerID  \
# 0  4.5        True    5868   St Peters Organic Ale     Bitter       974
# 1  4.5        True    5868   St Peters Organic Ale     Bitter       974
# 2  4.5        True    5868   St Peters Organic Ale     Bitter       974
# 3  4.5        True    5868   St Peters Organic Ale     Bitter       974
# 4  4.5        True    5868   St Peters Organic Ale     Bitter       974
#
#    review_overall reviewer_username  testData  \
# 0              14        abemorsten     False
# 1              11            jazz88     False
# 2              12          zach8270     False
# 3              14       Angeloregon     False
# 4              11        bierkoning     False
#
#                                          text_lookup     ...      \
# 0  [5868,  abemorsten, bottlecardinal pours light...     ...
# 1  [5868,  jazz88, bottle medium golden color tan...     ...
# 2  [5868,  zach8270, bottle  500 ml slightly hazy...     ...
# 3  [5868,  Angeloregon, updated aug 21 2008 malty...     ...
# 4  [5868,  bierkoning, orange color head light ho...     ...
#
#    distance_from_july_maxMonthsFromJuly_prodAgg  \
# 0                                             6
# 1                                             6
# 2                                             6
# 3                                             6
# 4                                             6
#
#    distance_from_july_medianMonthsFromJuly_prodAgg  \
# 0                                              3.0
# 1                                              3.0
# 2                                              3.0
# 3                                              3.0
# 4                                              3.0
#
#    reviewer_username_user_count  rate_of_posting_prodAgg  \
# 0                           306             9.783610e-07
# 1                           306             9.783610e-07
# 2                           306             9.783610e-07
# 3                           306             9.783610e-07
# 4                           306             9.783610e-07
#
#    weekend_review_ratio_prodAgg  aromaSVD appearanaceSVD palateSVD  tasteSVD  \
# 0                      0.447712  5.798785       3.250575  3.344836  5.379055
# 1                      0.447712  6.358591       2.913058  2.928688  5.262634
# 2                      0.447712  5.981086       2.971897  3.070367  5.419182
# 3                      0.447712  6.223292       3.548265  3.273529  5.545698
# 4                      0.447712  6.302348       2.869591  2.486358  6.189397
#
#    overallSVD
# 0   13.530825
# 1   12.470336
# 2   13.411647
# 3   14.397025
# 4   11.354125
#
# [5 rows x 153 columns]

# %%
df=df.drop(['text_lookup'], axis=1)

# %%
df.dtypes
# Out:
# abv                                                float64
# abv_listed                                            bool
# beerID                                               int64
# beer_name                                           object
# beer_style                                          object
# brewerID                                             int64
# review_overall                                       int64
# reviewer_username                                   object
# testData                                              bool
# vader_neg_avgVaderNeg                              float64
# vader_neg_medianVaderNeg                           float64
# vader_neg_maxVaderNeg                              float64
# vader_neg_minVaderNeg                              float64
# vader_neg_vaderNegRange                            float64
# month_number_of_months                               int64
# month_most_common_month                             object
# text_lookup_text_list                               object
# abv_listed_num_abv_listed                            int64
# brewerID_num_brewers                                 int64
# weekday_central_most_common_weekday                 object
# weekday_central_number_of_weekdays                   int64
# review_overall_avgOverallScore                     float64
# review_overall_maxOverallScore                       int64
# review_overall_medianOverallScore                  float64
# review_overall_overallScoreRange                     int64
# review_overall_minOverallScore                       int64
# beerID_beerID_count                                  int64
# review_palate_avgPalateScore                       float64
# review_palate_medianPalateScore                    float64
# review_palate_minPalateScore                         int64
#                                                     ...
# review_appearance_medianAppearanceScore_prodAgg    float64
# review_palate_avgPalateScore_prodAgg               float64
# review_palate_medianPalateScore_prodAgg            float64
# review_palate_minPalateScore_prodAgg                 int64
# review_palate_palateScoreRange_prodAgg               int64
# review_palate_maxPalateScore_prodAgg                 int64
# review_taste_maxTasteScore_prodAgg                   int64
# review_taste_avgTasteScore_prodAgg                 float64
# review_taste_medianTasteScore_prodAgg              float64
# review_taste_minTasteScore_prodAgg                   int64
# review_taste_tasteScoreRange_prodAgg                 int64
# weekend_review_num_weekend_reviews_prodAgg         float64
# abv_avgABV_prodAgg                                 float64
# abv_minABV_prodAgg                                 float64
# abv_ABVrange_prodAgg                               float64
# abv_maxABV_prodAgg                                 float64
# abv_medianABV_prodAgg                              float64
# distance_from_july_monthsFromJulyRange_prodAgg       int64
# distance_from_july_avgMonthsFromJuly_prodAgg       float64
# distance_from_july_minMonthsFromJuly_prodAgg         int64
# distance_from_july_maxMonthsFromJuly_prodAgg         int64
# distance_from_july_medianMonthsFromJuly_prodAgg    float64
# reviewer_username_user_count                         int64
# rate_of_posting_prodAgg                            float64
# weekend_review_ratio_prodAgg                       float64
# aromaSVD                                           float64
# appearanaceSVD                                     float64
# palateSVD                                          float64
# tasteSVD                                           float64
# overallSVD                                         float64
# Length: 152, dtype: object

# %%
df.select_dtypes(include=['object','bool']).copy().dtypes
# Out:
# abv_listed                                       bool
# beer_name                                      object
# beer_style                                     object
# reviewer_username                              object
# testData                                         bool
# month_most_common_month                        object
# text_lookup_text_list                          object
# weekday_central_most_common_weekday            object
# month_most_common_month_prodAgg                object
# text_lookup_text_list_prodAgg                  object
# weekday_central_most_common_weekday_prodAgg    object
# beer_style_numBeerStyles_prodAgg               object
# dtype: object

# %%
df['beer_style'].nunique()
# Out:
# 89

# %%
df['beer_style_numBeerStyles_prodAgg']
# Out:
# 0                                 Bitter
# 1                                 Bitter
# 2                                 Bitter
# 3                                 Bitter
# 4                                 Bitter
# 5                                 Bitter
# 6                                 Bitter
# 7                                 Bitter
# 8                                 Bitter
# 9                                 Bitter
# 10                                Bitter
# 11                                Bitter
# 12                                Bitter
# 13                                Bitter
# 14                                Bitter
# 15                                Bitter
# 16                                Bitter
# 17                                Bitter
# 18                                Bitter
# 19                                Bitter
# 20                                Bitter
# 21                                Bitter
# 22                                Bitter
# 23                                Bitter
# 24                                Bitter
# 25                                Bitter
# 26                                Bitter
# 27                                Bitter
# 28                                Bitter
# 29                                Bitter
#                        ...
# 1488922             Golden Ale/Blond Ale
# 1488923             Golden Ale/Blond Ale
# 1488924                   Saké - Infused
# 1488925                        Irish Ale
# 1488926     India Pale Ale &#40;IPA&#41;
# 1488927              Imperial/Double IPA
# 1488928                            Cider
# 1488929                            Cider
# 1488930                         Pilsener
# 1488931             Spice/Herb/Vegetable
# 1488932                      Heller Bock
# 1488933                           Bitter
# 1488934                           Bitter
# 1488935                     Dunkler Bock
# 1488936                      Sweet Stout
# 1488937                            Stout
# 1488938                     Dunkler Bock
# 1488939             Golden Ale/Blond Ale
# 1488940                   Imperial Stout
# 1488941                      Belgian Ale
# 1488942                   Imperial Stout
# 1488943             Spice/Herb/Vegetable
# 1488944                       Fruit Beer
# 1488945                           Smoked
# 1488946                         Pilsener
# 1488947             Golden Ale/Blond Ale
# 1488948                             Mead
# 1488949                            Cider
# 1488950             Golden Ale/Blond Ale
# 1488951                     Dunkler Bock
# Name: beer_style_numBeerStyles_prodAgg, Length: 1488952, dtype: object

# %% [markdown]
# ### One hot encoding of non-numeric columns

# %%
# For the moment, won't tokenize anything with very high cardinality
df=pd.get_dummies(df, columns=["beer_style", "month_most_common_month",
                                "weekday_central_most_common_weekday",
                               "weekday_central_most_common_weekday_prodAgg",
                               "month_most_common_month_prodAgg"],
               prefix=["beerStyle", "commonMonth", "commonDay", "commonDayProd", "commonMonthProd"])

# %%
df.columns.values
# Out:
# array(['abv', 'abv_listed', 'beerID', 'beer_name', 'brewerID',
#        'review_overall', 'reviewer_username', 'testData',
#        'vader_neg_avgVaderNeg', 'vader_neg_medianVaderNeg',
#        'vader_neg_maxVaderNeg', 'vader_neg_minVaderNeg',
#        'vader_neg_vaderNegRange', 'month_number_of_months',
#        'text_lookup_text_list', 'abv_listed_num_abv_listed',
#        'brewerID_num_brewers', 'weekday_central_number_of_weekdays',
#        'review_overall_avgOverallScore', 'review_overall_maxOverallScore',
#        'review_overall_medianOverallScore',
#        'review_overall_overallScoreRange',
#        'review_overall_minOverallScore', 'beerID_beerID_count',
#        'review_palate_avgPalateScore', 'review_palate_medianPalateScore',
#        'review_palate_minPalateScore', 'review_palate_palateScoreRange',
#        'review_palate_maxPalateScore',
#        'time_from_beginning_TimestampRange',
#        'time_from_beginning_medianTimestamp',
#        'time_from_beginning_avgTimestamp',
#        'time_from_beginning_maxTimestamp',
#        'time_from_beginning_minTimestamp',
#        'review_appearance_avgAppearanceScore',
#        'review_appearance_minAppearanceScore',
#        'review_appearance_maxAppearanceScore',
#        'review_appearance_appearanceScoreRange',
#        'review_appearance_medianAppearanceScore',
#        'review_taste_maxTasteScore', 'review_taste_avgTasteScore',
#        'review_taste_medianTasteScore', 'review_taste_minTasteScore',
#        'review_taste_tasteScoreRange', 'vader_neu_vaderNeuRange',
#        'vader_neu_avgVaderNeu', 'vader_neu_medianVaderNeu',
#        'vader_neu_maxVaderNeu', 'vader_neu_minVaderNeu',
#        'review_aroma_aromaScoreRange', 'review_aroma_medianAromaScore',
#        'review_aroma_avgAromaScore', 'review_aroma_minAromaScore',
#        'review_aroma_maxAromaScore', 'weekend_review_num_weekend_reviews',
#        'abv_avgABV', 'abv_minABV', 'abv_ABVrange', 'abv_maxABV',
#        'abv_medianABV', 'distance_from_july_monthsFromJulyRange',
#        'distance_from_july_avgMonthsFromJuly',
#        'distance_from_july_minMonthsFromJuly',
#        'distance_from_july_maxMonthsFromJuly',
#        'distance_from_july_medianMonthsFromJuly',
#        'beer_style_numBeerStyles', 'vader_pos_minVaderPos',
#        'vader_pos_avgVaderPos', 'vader_pos_vaderPosRange',
#        'vader_pos_maxVaderPos', 'vader_pos_medianVaderPos',
#        'beer_variety_index', 'beerStyle_variety_index',
#        'brewer_variety_index', 'rate_of_posting', 'weekday_variety_index',
#        'month_variety_index', 'weekend_review_ratio',
#        'vader_neg_avgVaderNeg_prodAgg', 'vader_neg_medianVaderNeg_prodAgg',
#        'vader_neg_maxVaderNeg_prodAgg', 'vader_neg_minVaderNeg_prodAgg',
#        'vader_neg_vaderNegRange_prodAgg', 'month_number_of_months_prodAgg',
#        'text_lookup_text_list_prodAgg',
#        'abv_listed_num_abv_listed_prodAgg',
#        'review_aroma_aromaScoreRange_prodAgg',
#        'review_aroma_medianAromaScore_prodAgg',
#        'review_aroma_avgAromaScore_prodAgg',
#        'review_aroma_minAromaScore_prodAgg',
#        'review_aroma_maxAromaScore_prodAgg',
#        'weekday_central_number_of_weekdays_prodAgg',
#        'review_overall_avgOverallScore_prodAgg',
#        'review_overall_maxOverallScore_prodAgg',
#        'review_overall_medianOverallScore_prodAgg',
#        'review_overall_overallScoreRange_prodAgg',
#        'review_overall_minOverallScore_prodAgg',
#        'vader_neu_vaderNeuRange_prodAgg', 'vader_neu_avgVaderNeu_prodAgg',
#        'vader_neu_medianVaderNeu_prodAgg', 'vader_neu_maxVaderNeu_prodAgg',
#        'vader_neu_minVaderNeu_prodAgg', 'vader_pos_minVaderPos_prodAgg',
#        'vader_pos_avgVaderPos_prodAgg', 'vader_pos_vaderPosRange_prodAgg',
#        'vader_pos_maxVaderPos_prodAgg', 'vader_pos_medianVaderPos_prodAgg',
#        'beer_style_numBeerStyles_prodAgg',
#        'time_from_beginning_TimestampRange_prodAgg',
#        'time_from_beginning_medianTimestamp_prodAgg',
#        'time_from_beginning_avgTimestamp_prodAgg',
#        'time_from_beginning_maxTimestamp_prodAgg',
#        'time_from_beginning_minTimestamp_prodAgg',
#        'review_appearance_avgAppearanceScore_prodAgg',
#        'review_appearance_minAppearanceScore_prodAgg',
#        'review_appearance_maxAppearanceScore_prodAgg',
#        'review_appearance_appearanceScoreRange_prodAgg',
#        'review_appearance_medianAppearanceScore_prodAgg',
#        'review_palate_avgPalateScore_prodAgg',
#        'review_palate_medianPalateScore_prodAgg',
#        'review_palate_minPalateScore_prodAgg',
#        'review_palate_palateScoreRange_prodAgg',
#        'review_palate_maxPalateScore_prodAgg',
#        'review_taste_maxTasteScore_prodAgg',
#        'review_taste_avgTasteScore_prodAgg',
#        'review_taste_medianTasteScore_prodAgg',
#        'review_taste_minTasteScore_prodAgg',
#        'review_taste_tasteScoreRange_prodAgg',
#        'weekend_review_num_weekend_reviews_prodAgg', 'abv_avgABV_prodAgg',
#        'abv_minABV_prodAgg', 'abv_ABVrange_prodAgg', 'abv_maxABV_prodAgg',
#        'abv_medianABV_prodAgg',
#        'distance_from_july_monthsFromJulyRange_prodAgg',
#        'distance_from_july_avgMonthsFromJuly_prodAgg',
#        'distance_from_july_minMonthsFromJuly_prodAgg',
#        'distance_from_july_maxMonthsFromJuly_prodAgg',
#        'distance_from_july_medianMonthsFromJuly_prodAgg',
#        'reviewer_username_user_count', 'rate_of_posting_prodAgg',
#        'weekend_review_ratio_prodAgg', 'aromaSVD', 'appearanaceSVD',
#        'palateSVD', 'tasteSVD', 'overallSVD', 'beerStyle_ Abbey Dubbel',
#        'beerStyle_ Abbey Tripel', 'beerStyle_ Abt/Quadrupel',
#        'beerStyle_ Altbier', 'beerStyle_ Amber Ale',
#        'beerStyle_ American Dark Lager', 'beerStyle_ American Pale Ale',
#        'beerStyle_ American Strong Ale', 'beerStyle_ Baltic Porter',
#        'beerStyle_ Barley Wine', 'beerStyle_ Belgian Ale',
#        'beerStyle_ Belgian Strong Ale',
#        'beerStyle_ Belgian White &#40;Witbier&#41;',
#        'beerStyle_ Berliner Weisse', 'beerStyle_ Bitter',
#        'beerStyle_ Bière de Garde', 'beerStyle_ Black IPA',
#        'beerStyle_ Bohemian Pilsener', 'beerStyle_ Brown Ale',
#        'beerStyle_ California Common', 'beerStyle_ Cider',
#        'beerStyle_ Classic German Pilsener', 'beerStyle_ Cream Ale',
#        'beerStyle_ Doppelbock', 'beerStyle_ Dortmunder/Helles',
#        'beerStyle_ Dry Stout', 'beerStyle_ Dunkel',
#        'beerStyle_ Dunkelweizen', 'beerStyle_ Dunkler Bock',
#        'beerStyle_ Eisbock', 'beerStyle_ English Pale Ale',
#        'beerStyle_ English Strong Ale', 'beerStyle_ Foreign Stout',
#        'beerStyle_ Fruit Beer', 'beerStyle_ German Hefeweizen',
#        'beerStyle_ German Kristallweizen',
#        'beerStyle_ Golden Ale/Blond Ale', 'beerStyle_ Heller Bock',
#        'beerStyle_ Ice Cider/Perry', 'beerStyle_ Imperial Stout',
#        'beerStyle_ Imperial/Double IPA',
#        'beerStyle_ Imperial/Strong Porter',
#        'beerStyle_ India Pale Ale &#40;IPA&#41;', 'beerStyle_ Irish Ale',
#        'beerStyle_ Kölsch', 'beerStyle_ Lambic - Faro',
#        'beerStyle_ Lambic - Fruit', 'beerStyle_ Lambic - Gueuze',
#        'beerStyle_ Lambic - Unblended', 'beerStyle_ Low Alcohol',
#        'beerStyle_ Malt Liquor', 'beerStyle_ Mead', 'beerStyle_ Mild Ale',
#        'beerStyle_ Oktoberfest/Märzen', 'beerStyle_ Old Ale',
#        'beerStyle_ Pale Lager', 'beerStyle_ Perry', 'beerStyle_ Pilsener',
#        'beerStyle_ Porter', 'beerStyle_ Premium Bitter/ESB',
#        'beerStyle_ Premium Lager', 'beerStyle_ Saison',
#        'beerStyle_ Saké - Daiginjo', 'beerStyle_ Saké - Futsu-shu',
#        'beerStyle_ Saké - Genshu', 'beerStyle_ Saké - Ginjo',
#        'beerStyle_ Saké - Honjozo', 'beerStyle_ Saké - Infused',
#        'beerStyle_ Saké - Junmai', 'beerStyle_ Saké - Koshu',
#        'beerStyle_ Saké - Namasaké', 'beerStyle_ Saké - Nigori',
#        'beerStyle_ Saké - Taru', 'beerStyle_ Saké - Tokubetsu',
#        'beerStyle_ Schwarzbier', 'beerStyle_ Scotch Ale',
#        'beerStyle_ Scottish Ale', 'beerStyle_ Smoked',
#        'beerStyle_ Sour Ale/Wild Ale', 'beerStyle_ Specialty Grain',
#        'beerStyle_ Spice/Herb/Vegetable', 'beerStyle_ Stout',
#        'beerStyle_ Strong Pale Lager/Imperial Pils',
#        'beerStyle_ Sweet Stout', 'beerStyle_ Traditional Ale',
#        'beerStyle_ Vienna', 'beerStyle_ Weizen Bock',
#        'beerStyle_ Wheat Ale', 'beerStyle_ Zwickel/Keller/Landbier',
#        'commonMonth_01', 'commonMonth_02', 'commonMonth_03',
#        'commonMonth_04', 'commonMonth_05', 'commonMonth_06',
#        'commonMonth_07', 'commonMonth_08', 'commonMonth_09',
#        'commonMonth_10', 'commonMonth_11', 'commonMonth_12',
#        'commonDay_Friday', 'commonDay_Monday', 'commonDay_Saturday',
#        'commonDay_Sunday', 'commonDay_Thursday', 'commonDay_Tuesday',
#        'commonDay_Wednesday', 'commonDayProd_Friday',
#        'commonDayProd_Monday', 'commonDayProd_Saturday',
#        'commonDayProd_Sunday', 'commonDayProd_Thursday',
#        'commonDayProd_Tuesday', 'commonDayProd_Wednesday',
#        'commonMonthProd_01', 'commonMonthProd_02', 'commonMonthProd_03',
#        'commonMonthProd_04', 'commonMonthProd_05', 'commonMonthProd_06',
#        'commonMonthProd_07', 'commonMonthProd_08', 'commonMonthProd_09',
#        'commonMonthProd_10', 'commonMonthProd_11', 'commonMonthProd_12'], dtype=object)

# %% [markdown]
# Create a list of only numeric columns to fit on

# %%
training_columns=list(df.columns.values)
notTraining=['abv_listed','beerID','beer_name','beer_style','brewerID','reviewer_username','testData',
             'month_most_common_month','month_most_common_month', 'weekday_central_most_common_weekday',
             'beer_style_numBeerStyles_prodAgg','text_lookup_text_list',
             'weekday_central_most_common_weekday_prodAgg','month_most_common_month_prodAgg',
             'text_lookup_text_list_prodAgg','review_overall','benchmarkSVD']
for col in notTraining:
    if col in training_columns:
        training_columns.remove(col)
    
training_columns
# Out:
# ['abv',
#  'vader_neg_avgVaderNeg',
#  'vader_neg_medianVaderNeg',
#  'vader_neg_maxVaderNeg',
#  'vader_neg_minVaderNeg',
#  'vader_neg_vaderNegRange',
#  'month_number_of_months',
#  'abv_listed_num_abv_listed',
#  'brewerID_num_brewers',
#  'weekday_central_number_of_weekdays',
#  'review_overall_avgOverallScore',
#  'review_overall_maxOverallScore',
#  'review_overall_medianOverallScore',
#  'review_overall_overallScoreRange',
#  'review_overall_minOverallScore',
#  'beerID_beerID_count',
#  'review_palate_avgPalateScore',
#  'review_palate_medianPalateScore',
#  'review_palate_minPalateScore',
#  'review_palate_palateScoreRange',
#  'review_palate_maxPalateScore',
#  'time_from_beginning_TimestampRange',
#  'time_from_beginning_medianTimestamp',
#  'time_from_beginning_avgTimestamp',
#  'time_from_beginning_maxTimestamp',
#  'time_from_beginning_minTimestamp',
#  'review_appearance_avgAppearanceScore',
#  'review_appearance_minAppearanceScore',
#  'review_appearance_maxAppearanceScore',
#  'review_appearance_appearanceScoreRange',
#  'review_appearance_medianAppearanceScore',
#  'review_taste_maxTasteScore',
#  'review_taste_avgTasteScore',
#  'review_taste_medianTasteScore',
#  'review_taste_minTasteScore',
#  'review_taste_tasteScoreRange',
#  'vader_neu_vaderNeuRange',
#  'vader_neu_avgVaderNeu',
#  'vader_neu_medianVaderNeu',
#  'vader_neu_maxVaderNeu',
#  'vader_neu_minVaderNeu',
#  'review_aroma_aromaScoreRange',
#  'review_aroma_medianAromaScore',
#  'review_aroma_avgAromaScore',
#  'review_aroma_minAromaScore',
#  'review_aroma_maxAromaScore',
#  'weekend_review_num_weekend_reviews',
#  'abv_avgABV',
#  'abv_minABV',
#  'abv_ABVrange',
#  'abv_maxABV',
#  'abv_medianABV',
#  'distance_from_july_monthsFromJulyRange',
#  'distance_from_july_avgMonthsFromJuly',
#  'distance_from_july_minMonthsFromJuly',
#  'distance_from_july_maxMonthsFromJuly',
#  'distance_from_july_medianMonthsFromJuly',
#  'beer_style_numBeerStyles',
#  'vader_pos_minVaderPos',
#  'vader_pos_avgVaderPos',
#  'vader_pos_vaderPosRange',
#  'vader_pos_maxVaderPos',
#  'vader_pos_medianVaderPos',
#  'beer_variety_index',
#  'beerStyle_variety_index',
#  'brewer_variety_index',
#  'rate_of_posting',
#  'weekday_variety_index',
#  'month_variety_index',
#  'weekend_review_ratio',
#  'vader_neg_avgVaderNeg_prodAgg',
#  'vader_neg_medianVaderNeg_prodAgg',
#  'vader_neg_maxVaderNeg_prodAgg',
#  'vader_neg_minVaderNeg_prodAgg',
#  'vader_neg_vaderNegRange_prodAgg',
#  'month_number_of_months_prodAgg',
#  'abv_listed_num_abv_listed_prodAgg',
#  'review_aroma_aromaScoreRange_prodAgg',
#  'review_aroma_medianAromaScore_prodAgg',
#  'review_aroma_avgAromaScore_prodAgg',
#  'review_aroma_minAromaScore_prodAgg',
#  'review_aroma_maxAromaScore_prodAgg',
#  'weekday_central_number_of_weekdays_prodAgg',
#  'review_overall_avgOverallScore_prodAgg',
#  'review_overall_maxOverallScore_prodAgg',
#  'review_overall_medianOverallScore_prodAgg',
#  'review_overall_overallScoreRange_prodAgg',
#  'review_overall_minOverallScore_prodAgg',
#  'vader_neu_vaderNeuRange_prodAgg',
#  'vader_neu_avgVaderNeu_prodAgg',
#  'vader_neu_medianVaderNeu_prodAgg',
#  'vader_neu_maxVaderNeu_prodAgg',
#  'vader_neu_minVaderNeu_prodAgg',
#  'vader_pos_minVaderPos_prodAgg',
#  'vader_pos_avgVaderPos_prodAgg',
#  'vader_pos_vaderPosRange_prodAgg',
#  'vader_pos_maxVaderPos_prodAgg',
#  'vader_pos_medianVaderPos_prodAgg',
#  'time_from_beginning_TimestampRange_prodAgg',
#  'time_from_beginning_medianTimestamp_prodAgg',
#  'time_from_beginning_avgTimestamp_prodAgg',
#  'time_from_beginning_maxTimestamp_prodAgg',
#  'time_from_beginning_minTimestamp_prodAgg',
#  'review_appearance_avgAppearanceScore_prodAgg',
#  'review_appearance_minAppearanceScore_prodAgg',
#  'review_appearance_maxAppearanceScore_prodAgg',
#  'review_appearance_appearanceScoreRange_prodAgg',
#  'review_appearance_medianAppearanceScore_prodAgg',
#  'review_palate_avgPalateScore_prodAgg',
#  'review_palate_medianPalateScore_prodAgg',
#  'review_palate_minPalateScore_prodAgg',
#  'review_palate_palateScoreRange_prodAgg',
#  'review_palate_maxPalateScore_prodAgg',
#  'review_taste_maxTasteScore_prodAgg',
#  'review_taste_avgTasteScore_prodAgg',
#  'review_taste_medianTasteScore_prodAgg',
#  'review_taste_minTasteScore_prodAgg',
#  'review_taste_tasteScoreRange_prodAgg',
#  'weekend_review_num_weekend_reviews_prodAgg',
#  'abv_avgABV_prodAgg',
#  'abv_minABV_prodAgg',
#  'abv_ABVrange_prodAgg',
#  'abv_maxABV_prodAgg',
#  'abv_medianABV_prodAgg',
#  'distance_from_july_monthsFromJulyRange_prodAgg',
#  'distance_from_july_avgMonthsFromJuly_prodAgg',
#  'distance_from_july_minMonthsFromJuly_prodAgg',
#  'distance_from_july_maxMonthsFromJuly_prodAgg',
#  'distance_from_july_medianMonthsFromJuly_prodAgg',
#  'reviewer_username_user_count',
#  'rate_of_posting_prodAgg',
#  'weekend_review_ratio_prodAgg',
#  'aromaSVD',
#  'appearanaceSVD',
#  'palateSVD',
#  'tasteSVD',
#  'overallSVD',
#  'beerStyle_ Abbey Dubbel',
#  'beerStyle_ Abbey Tripel',
#  'beerStyle_ Abt/Quadrupel',
#  'beerStyle_ Altbier',
#  'beerStyle_ Amber Ale',
#  'beerStyle_ American Dark Lager',
#  'beerStyle_ American Pale Ale',
#  'beerStyle_ American Strong Ale',
#  'beerStyle_ Baltic Porter',
#  'beerStyle_ Barley Wine',
#  'beerStyle_ Belgian Ale',
#  'beerStyle_ Belgian Strong Ale',
#  'beerStyle_ Belgian White &#40;Witbier&#41;',
#  'beerStyle_ Berliner Weisse',
#  'beerStyle_ Bitter',
#  'beerStyle_ Bière de Garde',
#  'beerStyle_ Black IPA',
#  'beerStyle_ Bohemian Pilsener',
#  'beerStyle_ Brown Ale',
#  'beerStyle_ California Common',
#  'beerStyle_ Cider',
#  'beerStyle_ Classic German Pilsener',
#  'beerStyle_ Cream Ale',
#  'beerStyle_ Doppelbock',
#  'beerStyle_ Dortmunder/Helles',
#  'beerStyle_ Dry Stout',
#  'beerStyle_ Dunkel',
#  'beerStyle_ Dunkelweizen',
#  'beerStyle_ Dunkler Bock',
#  'beerStyle_ Eisbock',
#  'beerStyle_ English Pale Ale',
#  'beerStyle_ English Strong Ale',
#  'beerStyle_ Foreign Stout',
#  'beerStyle_ Fruit Beer',
#  'beerStyle_ German Hefeweizen',
#  'beerStyle_ German Kristallweizen',
#  'beerStyle_ Golden Ale/Blond Ale',
#  'beerStyle_ Heller Bock',
#  'beerStyle_ Ice Cider/Perry',
#  'beerStyle_ Imperial Stout',
#  'beerStyle_ Imperial/Double IPA',
#  'beerStyle_ Imperial/Strong Porter',
#  'beerStyle_ India Pale Ale &#40;IPA&#41;',
#  'beerStyle_ Irish Ale',
#  'beerStyle_ Kölsch',
#  'beerStyle_ Lambic - Faro',
#  'beerStyle_ Lambic - Fruit',
#  'beerStyle_ Lambic - Gueuze',
#  'beerStyle_ Lambic - Unblended',
#  'beerStyle_ Low Alcohol',
#  'beerStyle_ Malt Liquor',
#  'beerStyle_ Mead',
#  'beerStyle_ Mild Ale',
#  'beerStyle_ Oktoberfest/Märzen',
#  'beerStyle_ Old Ale',
#  'beerStyle_ Pale Lager',
#  'beerStyle_ Perry',
#  'beerStyle_ Pilsener',
#  'beerStyle_ Porter',
#  'beerStyle_ Premium Bitter/ESB',
#  'beerStyle_ Premium Lager',
#  'beerStyle_ Saison',
#  'beerStyle_ Saké - Daiginjo',
#  'beerStyle_ Saké - Futsu-shu',
#  'beerStyle_ Saké - Genshu',
#  'beerStyle_ Saké - Ginjo',
#  'beerStyle_ Saké - Honjozo',
#  'beerStyle_ Saké - Infused',
#  'beerStyle_ Saké - Junmai',
#  'beerStyle_ Saké - Koshu',
#  'beerStyle_ Saké - Namasaké',
#  'beerStyle_ Saké - Nigori',
#  'beerStyle_ Saké - Taru',
#  'beerStyle_ Saké - Tokubetsu',
#  'beerStyle_ Schwarzbier',
#  'beerStyle_ Scotch Ale',
#  'beerStyle_ Scottish Ale',
#  'beerStyle_ Smoked',
#  'beerStyle_ Sour Ale/Wild Ale',
#  'beerStyle_ Specialty Grain',
#  'beerStyle_ Spice/Herb/Vegetable',
#  'beerStyle_ Stout',
#  'beerStyle_ Strong Pale Lager/Imperial Pils',
#  'beerStyle_ Sweet Stout',
#  'beerStyle_ Traditional Ale',
#  'beerStyle_ Vienna',
#  'beerStyle_ Weizen Bock',
#  'beerStyle_ Wheat Ale',
#  'beerStyle_ Zwickel/Keller/Landbier',
#  'commonMonth_01',
#  'commonMonth_02',
#  'commonMonth_03',
#  'commonMonth_04',
#  'commonMonth_05',
#  'commonMonth_06',
#  'commonMonth_07',
#  'commonMonth_08',
#  'commonMonth_09',
#  'commonMonth_10',
#  'commonMonth_11',
#  'commonMonth_12',
#  'commonDay_Friday',
#  'commonDay_Monday',
#  'commonDay_Saturday',
#  'commonDay_Sunday',
#  'commonDay_Thursday',
#  'commonDay_Tuesday',
#  'commonDay_Wednesday',
#  'commonDayProd_Friday',
#  'commonDayProd_Monday',
#  'commonDayProd_Saturday',
#  'commonDayProd_Sunday',
#  'commonDayProd_Thursday',
#  'commonDayProd_Tuesday',
#  'commonDayProd_Wednesday',
#  'commonMonthProd_01',
#  'commonMonthProd_02',
#  'commonMonthProd_03',
#  'commonMonthProd_04',
#  'commonMonthProd_05',
#  'commonMonthProd_06',
#  'commonMonthProd_07',
#  'commonMonthProd_08',
#  'commonMonthProd_09',
#  'commonMonthProd_10',
#  'commonMonthProd_11',
#  'commonMonthProd_12']

# %%
df[training_columns].select_dtypes(include=['object','bool']).copy().dtypes
# Out:
# Series([], dtype: object)

# %%
np.any(np.isnan(df[training_columns]))
# Out:
# False

# %%
isInfinite=(~np.isfinite(df[training_columns])).sum()

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 3):
    print(isInfinite)
# Out:
# abv                                                    0
# vader_neg_avgVaderNeg                                  0
# vader_neg_medianVaderNeg                               0
# vader_neg_maxVaderNeg                                  0
# vader_neg_minVaderNeg                                  0
# vader_neg_vaderNegRange                                0
# month_number_of_months                                 0
# abv_listed_num_abv_listed                              0
# brewerID_num_brewers                                   0
# weekday_central_number_of_weekdays                     0
# review_overall_avgOverallScore                         0
# review_overall_maxOverallScore                         0
# review_overall_medianOverallScore                      0
# review_overall_overallScoreRange                       0
# review_overall_minOverallScore                         0
# beerID_beerID_count                                    0
# review_palate_avgPalateScore                           0
# review_palate_medianPalateScore                        0
# review_palate_minPalateScore                           0
# review_palate_palateScoreRange                         0
# review_palate_maxPalateScore                           0
# time_from_beginning_TimestampRange                     0
# time_from_beginning_medianTimestamp                    0
# time_from_beginning_avgTimestamp                       0
# time_from_beginning_maxTimestamp                       0
# time_from_beginning_minTimestamp                       0
# review_appearance_avgAppearanceScore                   0
# review_appearance_minAppearanceScore                   0
# review_appearance_maxAppearanceScore                   0
# review_appearance_appearanceScoreRange                 0
# review_appearance_medianAppearanceScore                0
# review_taste_maxTasteScore                             0
# review_taste_avgTasteScore                             0
# review_taste_medianTasteScore                          0
# review_taste_minTasteScore                             0
# review_taste_tasteScoreRange                           0
# vader_neu_vaderNeuRange                                0
# vader_neu_avgVaderNeu                                  0
# vader_neu_medianVaderNeu                               0
# vader_neu_maxVaderNeu                                  0
# vader_neu_minVaderNeu                                  0
# review_aroma_aromaScoreRange                           0
# review_aroma_medianAromaScore                          0
# review_aroma_avgAromaScore                             0
# review_aroma_minAromaScore                             0
# review_aroma_maxAromaScore                             0
# weekend_review_num_weekend_reviews                     0
# abv_avgABV                                             0
# abv_minABV                                             0
# abv_ABVrange                                           0
# abv_maxABV                                             0
# abv_medianABV                                          0
# distance_from_july_monthsFromJulyRange                 0
# distance_from_july_avgMonthsFromJuly                   0
# distance_from_july_minMonthsFromJuly                   0
# distance_from_july_maxMonthsFromJuly                   0
# distance_from_july_medianMonthsFromJuly                0
# beer_style_numBeerStyles                               0
# vader_pos_minVaderPos                                  0
# vader_pos_avgVaderPos                                  0
# vader_pos_vaderPosRange                                0
# vader_pos_maxVaderPos                                  0
# vader_pos_medianVaderPos                               0
# beer_variety_index                                     0
# beerStyle_variety_index                                0
# brewer_variety_index                                   0
# rate_of_posting                                    15001
# weekday_variety_index                                  0
# month_variety_index                                    0
# weekend_review_ratio                                   0
# vader_neg_avgVaderNeg_prodAgg                          0
# vader_neg_medianVaderNeg_prodAgg                       0
# vader_neg_maxVaderNeg_prodAgg                          0
# vader_neg_minVaderNeg_prodAgg                          0
# vader_neg_vaderNegRange_prodAgg                        0
# month_number_of_months_prodAgg                         0
# abv_listed_num_abv_listed_prodAgg                      0
# review_aroma_aromaScoreRange_prodAgg                   0
# review_aroma_medianAromaScore_prodAgg                  0
# review_aroma_avgAromaScore_prodAgg                     0
# review_aroma_minAromaScore_prodAgg                     0
# review_aroma_maxAromaScore_prodAgg                     0
# weekday_central_number_of_weekdays_prodAgg             0
# review_overall_avgOverallScore_prodAgg                 0
# review_overall_maxOverallScore_prodAgg                 0
# review_overall_medianOverallScore_prodAgg              0
# review_overall_overallScoreRange_prodAgg               0
# review_overall_minOverallScore_prodAgg                 0
# vader_neu_vaderNeuRange_prodAgg                        0
# vader_neu_avgVaderNeu_prodAgg                          0
# vader_neu_medianVaderNeu_prodAgg                       0
# vader_neu_maxVaderNeu_prodAgg                          0
# vader_neu_minVaderNeu_prodAgg                          0
# vader_pos_minVaderPos_prodAgg                          0
# vader_pos_avgVaderPos_prodAgg                          0
# vader_pos_vaderPosRange_prodAgg                        0
# vader_pos_maxVaderPos_prodAgg                          0
# vader_pos_medianVaderPos_prodAgg                       0
# time_from_beginning_TimestampRange_prodAgg             0
# time_from_beginning_medianTimestamp_prodAgg            0
# time_from_beginning_avgTimestamp_prodAgg               0
# time_from_beginning_maxTimestamp_prodAgg               0
# time_from_beginning_minTimestamp_prodAgg               0
# review_appearance_avgAppearanceScore_prodAgg           0
# review_appearance_minAppearanceScore_prodAgg           0
# review_appearance_maxAppearanceScore_prodAgg           0
# review_appearance_appearanceScoreRange_prodAgg         0
# review_appearance_medianAppearanceScore_prodAgg        0
# review_palate_avgPalateScore_prodAgg                   0
# review_palate_medianPalateScore_prodAgg                0
# review_palate_minPalateScore_prodAgg                   0
# review_palate_palateScoreRange_prodAgg                 0
# review_palate_maxPalateScore_prodAgg                   0
# review_taste_maxTasteScore_prodAgg                     0
# review_taste_avgTasteScore_prodAgg                     0
# review_taste_medianTasteScore_prodAgg                  0
# review_taste_minTasteScore_prodAgg                     0
# review_taste_tasteScoreRange_prodAgg                   0
# weekend_review_num_weekend_reviews_prodAgg             0
# abv_avgABV_prodAgg                                     0
# abv_minABV_prodAgg                                     0
# abv_ABVrange_prodAgg                                   0
# abv_maxABV_prodAgg                                     0
# abv_medianABV_prodAgg                                  0
# distance_from_july_monthsFromJulyRange_prodAgg         0
# distance_from_july_avgMonthsFromJuly_prodAgg           0
# distance_from_july_minMonthsFromJuly_prodAgg           0
# distance_from_july_maxMonthsFromJuly_prodAgg           0
# distance_from_july_medianMonthsFromJuly_prodAgg        0
# reviewer_username_user_count                           0
# rate_of_posting_prodAgg                            35343
# weekend_review_ratio_prodAgg                           0
# aromaSVD                                               0
# appearanaceSVD                                         0
# palateSVD                                              0
# tasteSVD                                               0
# overallSVD                                             0
# beerStyle_ Abbey Dubbel                                0
# beerStyle_ Abbey Tripel                                0
# beerStyle_ Abt/Quadrupel                               0
# beerStyle_ Altbier                                     0
# beerStyle_ Amber Ale                                   0
# beerStyle_ American Dark Lager                         0
# beerStyle_ American Pale Ale                           0
# beerStyle_ American Strong Ale                         0
# beerStyle_ Baltic Porter                               0
# beerStyle_ Barley Wine                                 0
# beerStyle_ Belgian Ale                                 0
# beerStyle_ Belgian Strong Ale                          0
# beerStyle_ Belgian White &#40;Witbier&#41;             0
# beerStyle_ Berliner Weisse                             0
# beerStyle_ Bitter                                      0
# beerStyle_ Bière de Garde                              0
# beerStyle_ Black IPA                                   0
# beerStyle_ Bohemian Pilsener                           0
# beerStyle_ Brown Ale                                   0
# beerStyle_ California Common                           0
# beerStyle_ Cider                                       0
# beerStyle_ Classic German Pilsener                     0
# beerStyle_ Cream Ale                                   0
# beerStyle_ Doppelbock                                  0
# beerStyle_ Dortmunder/Helles                           0
# beerStyle_ Dry Stout                                   0
# beerStyle_ Dunkel                                      0
# beerStyle_ Dunkelweizen                                0
# beerStyle_ Dunkler Bock                                0
# beerStyle_ Eisbock                                     0
# beerStyle_ English Pale Ale                            0
# beerStyle_ English Strong Ale                          0
# beerStyle_ Foreign Stout                               0
# beerStyle_ Fruit Beer                                  0
# beerStyle_ German Hefeweizen                           0
# beerStyle_ German Kristallweizen                       0
# beerStyle_ Golden Ale/Blond Ale                        0
# beerStyle_ Heller Bock                                 0
# beerStyle_ Ice Cider/Perry                             0
# beerStyle_ Imperial Stout                              0
# beerStyle_ Imperial/Double IPA                         0
# beerStyle_ Imperial/Strong Porter                      0
# beerStyle_ India Pale Ale &#40;IPA&#41;                0
# beerStyle_ Irish Ale                                   0
# beerStyle_ Kölsch                                      0
# beerStyle_ Lambic - Faro                               0
# beerStyle_ Lambic - Fruit                              0
# beerStyle_ Lambic - Gueuze                             0
# beerStyle_ Lambic - Unblended                          0
# beerStyle_ Low Alcohol                                 0
# beerStyle_ Malt Liquor                                 0
# beerStyle_ Mead                                        0
# beerStyle_ Mild Ale                                    0
# beerStyle_ Oktoberfest/Märzen                          0
# beerStyle_ Old Ale                                     0
# beerStyle_ Pale Lager                                  0
# beerStyle_ Perry                                       0
# beerStyle_ Pilsener                                    0
# beerStyle_ Porter                                      0
# beerStyle_ Premium Bitter/ESB                          0
# beerStyle_ Premium Lager                               0
# beerStyle_ Saison                                      0
# beerStyle_ Saké - Daiginjo                             0
# beerStyle_ Saké - Futsu-shu                            0
# beerStyle_ Saké - Genshu                               0
# beerStyle_ Saké - Ginjo                                0
# beerStyle_ Saké - Honjozo                              0
# beerStyle_ Saké - Infused                              0
# beerStyle_ Saké - Junmai                               0
# beerStyle_ Saké - Koshu                                0
# beerStyle_ Saké - Namasaké                             0
# beerStyle_ Saké - Nigori                               0
# beerStyle_ Saké - Taru                                 0
# beerStyle_ Saké - Tokubetsu                            0
# beerStyle_ Schwarzbier                                 0
# beerStyle_ Scotch Ale                                  0
# beerStyle_ Scottish Ale                                0
# beerStyle_ Smoked                                      0
# beerStyle_ Sour Ale/Wild Ale                           0
# beerStyle_ Specialty Grain                             0
# beerStyle_ Spice/Herb/Vegetable                        0
# beerStyle_ Stout                                       0
# beerStyle_ Strong Pale Lager/Imperial Pils             0
# beerStyle_ Sweet Stout                                 0
# beerStyle_ Traditional Ale                             0
# beerStyle_ Vienna                                      0
# beerStyle_ Weizen Bock                                 0
# beerStyle_ Wheat Ale                                   0
# beerStyle_ Zwickel/Keller/Landbier                     0
# commonMonth_01                                         0
# commonMonth_02                                         0
# commonMonth_03                                         0
# commonMonth_04                                         0
# commonMonth_05                                         0
# commonMonth_06                                         0
# commonMonth_07                                         0
# commonMonth_08                                         0
# commonMonth_09                                         0
# commonMonth_10                                         0
# commonMonth_11                                         0
# commonMonth_12                                         0
# commonDay_Friday                                       0
# commonDay_Monday                                       0
# commonDay_Saturday                                     0
# commonDay_Sunday                                       0
# commonDay_Thursday                                     0
# commonDay_Tuesday                                      0
# commonDay_Wednesday                                    0
# commonDayProd_Friday                                   0
# commonDayProd_Monday                                   0
# commonDayProd_Saturday                                 0
# commonDayProd_Sunday                                   0
# commonDayProd_Thursday                                 0
# commonDayProd_Tuesday                                  0
# commonDayProd_Wednesday                                0
# commonMonthProd_01                                     0
# commonMonthProd_02                                     0
# commonMonthProd_03                                     0
# commonMonthProd_04                                     0
# commonMonthProd_05                                     0
# commonMonthProd_06                                     0
# commonMonthProd_07                                     0
# commonMonthProd_08                                     0
# commonMonthProd_09                                     0
# commonMonthProd_10                                     0
# commonMonthProd_11                                     0
# commonMonthProd_12                                     0
# dtype: int64

# %% [markdown]
# rate_of_posting and rate_of_posting_prodAgg both have inf values. Makes sense. Probably created during division. Would be created for users/products with just one review. Will fill these values with averages.

# %%
df=df.replace([np.inf, -np.inf], np.nan)

# %%
df['rate_of_posting'].fillna((df['rate_of_posting'].mean()), inplace=True)

# %%
df['rate_of_posting_prodAgg'].fillna((df['rate_of_posting_prodAgg'].mean()), inplace=True)

# %%
df_train=df[df['testData']==False]
df_test=df[df['testData']==True]

# %%
df_train['testData'].count()
# Out:
# 1284624

# %%
df_test['testData'].count()
# Out:
# 204328

# %% [markdown]
# Check the standard SVD errors on test set

# %%
mean_absolute_error(df_test['review_overall'],df_test['overallSVD'])
# Out:
# 1.8875064754361444

# %%
mean_squared_error(df_test['review_overall'],df_test['overallSVD'])
# Out:
# 6.2011613605819198

# %%
r2_score(df_test['review_overall'],df_test['overallSVD'])
# Out:
# 0.28759791556665748

# %%
df_train[training_columns].dtypes
# Out:
# abv                                       float64
# vader_neg_avgVaderNeg                     float64
# vader_neg_medianVaderNeg                  float64
# vader_neg_maxVaderNeg                     float64
# vader_neg_minVaderNeg                     float64
# vader_neg_vaderNegRange                   float64
# month_number_of_months                      int64
# abv_listed_num_abv_listed                   int64
# brewerID_num_brewers                        int64
# weekday_central_number_of_weekdays          int64
# review_overall_avgOverallScore            float64
# review_overall_maxOverallScore              int64
# review_overall_medianOverallScore         float64
# review_overall_overallScoreRange            int64
# review_overall_minOverallScore              int64
# beerID_beerID_count                         int64
# review_palate_avgPalateScore              float64
# review_palate_medianPalateScore           float64
# review_palate_minPalateScore                int64
# review_palate_palateScoreRange              int64
# review_palate_maxPalateScore                int64
# time_from_beginning_TimestampRange          int64
# time_from_beginning_medianTimestamp         int64
# time_from_beginning_avgTimestamp          float64
# time_from_beginning_maxTimestamp            int64
# time_from_beginning_minTimestamp            int64
# review_appearance_avgAppearanceScore      float64
# review_appearance_minAppearanceScore        int64
# review_appearance_maxAppearanceScore        int64
# review_appearance_appearanceScoreRange      int64
#                                            ...
# commonMonth_09                              uint8
# commonMonth_10                              uint8
# commonMonth_11                              uint8
# commonMonth_12                              uint8
# commonDay_Friday                            uint8
# commonDay_Monday                            uint8
# commonDay_Saturday                          uint8
# commonDay_Sunday                            uint8
# commonDay_Thursday                          uint8
# commonDay_Tuesday                           uint8
# commonDay_Wednesday                         uint8
# commonDayProd_Friday                        uint8
# commonDayProd_Monday                        uint8
# commonDayProd_Saturday                      uint8
# commonDayProd_Sunday                        uint8
# commonDayProd_Thursday                      uint8
# commonDayProd_Tuesday                       uint8
# commonDayProd_Wednesday                     uint8
# commonMonthProd_01                          uint8
# commonMonthProd_02                          uint8
# commonMonthProd_03                          uint8
# commonMonthProd_04                          uint8
# commonMonthProd_05                          uint8
# commonMonthProd_06                          uint8
# commonMonthProd_07                          uint8
# commonMonthProd_08                          uint8
# commonMonthProd_09                          uint8
# commonMonthProd_10                          uint8
# commonMonthProd_11                          uint8
# commonMonthProd_12                          uint8
# Length: 264, dtype: object

# %% [markdown]
# ### Linear Regression

# %%
lr = LinearRegression()
lr.fit(df_train[training_columns],df_train['review_overall'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_test_pred = lr.predict(df_test[training_columns])

# %%
mean_absolute_error(df_test['review_overall'], y_test_pred)
# Out:
# 1.6126863794106983

# %%
mean_squared_error(df_test['review_overall'], y_test_pred)
# Out:
# 4.7854467968649192

# %%
r2_score(df_test['review_overall'], y_test_pred)
# Out:
# 0.45023809657623337

# %%
set(zip(df_test[training_columns].columns.values, lr.coef_))
# Out:
# {('abv', 0.17311850869584686),
#  ('abv_ABVrange', 0.0063794125828851023),
#  ('abv_ABVrange_prodAgg', -2.4817849491876043e-06),
#  ('abv_avgABV', -0.20655040277435432),
#  ('abv_avgABV_prodAgg', -0.019525801156731859),
#  ('abv_listed_num_abv_listed', 0.00014032736059571411),
#  ('abv_listed_num_abv_listed_prodAgg', 0.00050176462502804497),
#  ('abv_maxABV', -0.005414944321216808),
#  ('abv_maxABV_prodAgg', -0.04805807064514056),
#  ('abv_medianABV', 0.0095511449128196091),
#  ('abv_medianABV_prodAgg', -0.048056666266404591),
#  ('abv_minABV', -0.0083551759201725417),
#  ('abv_minABV_prodAgg', -0.048056769552204059),
#  ('appearanaceSVD', -0.26994564520772002),
#  ('aromaSVD', 0.19297175285295509),
#  ('beerID_beerID_count', -0.00010591628437796319),
#  ('beerStyle_ Abbey Dubbel', -0.039132984059353948),
#  ('beerStyle_ Abbey Tripel', -0.1053473074285054),
#  ('beerStyle_ Abt/Quadrupel', -0.11983838542378011),
#  ('beerStyle_ Altbier', -0.045362201203219876),
#  ('beerStyle_ Amber Ale', -0.05445260032680288),
#  ('beerStyle_ American Dark Lager', -0.033275689788228036),
#  ('beerStyle_ American Pale Ale', -0.042591919354608265),
#  ('beerStyle_ American Strong Ale', -0.022216302362939366),
#  ('beerStyle_ Baltic Porter', -0.057004593706015072),
#  ('beerStyle_ Barley Wine', -0.039539608500788859),
#  ('beerStyle_ Belgian Ale', -0.036777402314829843),
#  ('beerStyle_ Belgian Strong Ale', -0.061055131816061703),
#  ('beerStyle_ Belgian White &#40;Witbier&#41;', -0.14785914867150041),
#  ('beerStyle_ Berliner Weisse', 0.066450624549437842),
#  ('beerStyle_ Bitter', -0.15849957469477971),
#  ('beerStyle_ Bière de Garde', -0.097297505191807798),
#  ('beerStyle_ Black IPA', 0.15992767223594528),
#  ('beerStyle_ Bohemian Pilsener', 0.091807256035119078),
#  ('beerStyle_ Brown Ale', -0.026430179922728669),
#  ('beerStyle_ California Common', 0.066809575793740028),
#  ('beerStyle_ Cider', -0.16683161892822362),
#  ('beerStyle_ Classic German Pilsener', -0.069851559302635868),
#  ('beerStyle_ Cream Ale', -0.21246529013189536),
#  ('beerStyle_ Doppelbock', -0.045174032943509523),
#  ('beerStyle_ Dortmunder/Helles', -0.025244577022714876),
#  ('beerStyle_ Dry Stout', -0.038464398799554544),
#  ('beerStyle_ Dunkel', -0.054473779008963663),
#  ('beerStyle_ Dunkelweizen', -0.049588362256582919),
#  ('beerStyle_ Dunkler Bock', -0.014415368589608568),
#  ('beerStyle_ Eisbock', 0.022063301627826881),
#  ('beerStyle_ English Pale Ale', -0.076674687337554781),
#  ('beerStyle_ English Strong Ale', -0.018576194349025243),
#  ('beerStyle_ Foreign Stout', -0.06797373943761037),
#  ('beerStyle_ Fruit Beer', -0.28215007917089885),
#  ('beerStyle_ German Hefeweizen', -0.12009642264510756),
#  ('beerStyle_ German Kristallweizen', -0.056973243820079789),
#  ('beerStyle_ Golden Ale/Blond Ale', -0.16435414137028381),
#  ('beerStyle_ Heller Bock', 0.015773029150722095),
#  ('beerStyle_ Ice Cider/Perry', 0.29313478985115116),
#  ('beerStyle_ Imperial Stout', -0.021451334833805902),
#  ('beerStyle_ Imperial/Double IPA', -0.10460287940992608),
#  ('beerStyle_ Imperial/Strong Porter', -0.041851926604299372),
#  ('beerStyle_ India Pale Ale &#40;IPA&#41;', -0.078371341621547685),
#  ('beerStyle_ Irish Ale', -0.10823796372194533),
#  ('beerStyle_ Kölsch', -0.036070047999580912),
#  ('beerStyle_ Lambic - Faro', 0.22661997766414621),
#  ('beerStyle_ Lambic - Fruit', -0.076439773226082863),
#  ('beerStyle_ Lambic - Gueuze', -0.0034971488989465893),
#  ('beerStyle_ Lambic - Unblended', 0.069426380323293832),
#  ('beerStyle_ Low Alcohol', -0.48504043923258067),
#  ('beerStyle_ Malt Liquor', -0.23355404072530295),
#  ('beerStyle_ Mead', 0.11060304101781959),
#  ('beerStyle_ Mild Ale', 0.0061021806461173389),
#  ('beerStyle_ Oktoberfest/Märzen', -0.046934755983866316),
#  ('beerStyle_ Old Ale', -0.016280414612478089),
#  ('beerStyle_ Pale Lager', -0.27237987030679456),
#  ('beerStyle_ Perry', -0.054340342112779202),
#  ('beerStyle_ Pilsener', -0.11450041660522695),
#  ('beerStyle_ Porter', -0.025483512989953994),
#  ('beerStyle_ Premium Bitter/ESB', -0.056049998698078696),
#  ('beerStyle_ Premium Lager', -0.094310142859907131),
#  ('beerStyle_ Saison', 0.040281563175077473),
#  ('beerStyle_ Saké - Daiginjo', 0.9274610552090925),
#  ('beerStyle_ Saké - Futsu-shu', -0.030601566278766368),
#  ('beerStyle_ Saké - Genshu', 0.86606008282579006),
#  ('beerStyle_ Saké - Ginjo', 0.07429040816489918),
#  ('beerStyle_ Saké - Honjozo', 0.61695934724651036),
#  ('beerStyle_ Saké - Infused', -0.64371641267717972),
#  ('beerStyle_ Saké - Junmai', 0.13236133992108295),
#  ('beerStyle_ Saké - Koshu', 1.3198691270398502),
#  ('beerStyle_ Saké - Namasaké', 0.49040729585811216),
#  ('beerStyle_ Saké - Nigori', 0.037108508889722669),
#  ('beerStyle_ Saké - Taru', 0.14651721280705118),
#  ('beerStyle_ Saké - Tokubetsu', -0.13508099702811105),
#  ('beerStyle_ Schwarzbier', -0.0093295713510992417),
#  ('beerStyle_ Scotch Ale', -0.10161317351264559),
#  ('beerStyle_ Scottish Ale', -0.015223924521191701),
#  ('beerStyle_ Smoked', -0.014095075927238021),
#  ('beerStyle_ Sour Ale/Wild Ale', 0.096637367365594251),
#  ('beerStyle_ Specialty Grain', -0.038583225850175762),
#  ('beerStyle_ Spice/Herb/Vegetable', -0.16664505010375308),
#  ('beerStyle_ Stout', -0.035593875634995831),
#  ('beerStyle_ Strong Pale Lager/Imperial Pils', -0.09174830269913814),
#  ('beerStyle_ Sweet Stout', 0.027605369374700039),
#  ('beerStyle_ Traditional Ale', -0.085447825307071956),
#  ('beerStyle_ Vienna', 0.029422463063971005),
#  ('beerStyle_ Weizen Bock', -0.010000422917112894),
#  ('beerStyle_ Wheat Ale', -0.10891580862716843),
#  ('beerStyle_ Zwickel/Keller/Landbier', -0.026958253680358868),
#  ('beerStyle_variety_index', -0.26368150004114188),
#  ('beer_style_numBeerStyles', -0.0050191178223712996),
#  ('beer_variety_index', -0.21441491329667972),
#  ('brewerID_num_brewers', 5.1240559686686893e-05),
#  ('brewer_variety_index', -0.21445463788469787),
#  ('commonDayProd_Friday', 0.0092886393484690188),
#  ('commonDayProd_Monday', -0.00091202468878126552),
#  ('commonDayProd_Saturday', -0.015523484951328825),
#  ('commonDayProd_Sunday', 0.01881558951941642),
#  ('commonDayProd_Thursday', 0.026308171321984375),
#  ('commonDayProd_Tuesday', -0.032688545920000145),
#  ('commonDayProd_Wednesday', -0.0055480008831221284),
#  ('commonDay_Friday', 0.0059944103551274885),
#  ('commonDay_Monday', -0.010137878496732144),
#  ('commonDay_Saturday', -0.0013952952077396219),
#  ('commonDay_Sunday', -0.017434437674398673),
#  ('commonDay_Thursday', 0.0069146879076600332),
#  ('commonDay_Tuesday', 0.0096044724871235942),
#  ('commonDay_Wednesday', 0.0067391077531297472),
#  ('commonMonthProd_01', -0.013096272836776279),
#  ('commonMonthProd_02', 0.018667401166265307),
#  ('commonMonthProd_03', 0.0062272078158418509),
#  ('commonMonthProd_04', 0.012095568435890325),
#  ('commonMonthProd_05', -0.0097091313981607641),
#  ('commonMonthProd_06', 0.014264997445515348),
#  ('commonMonthProd_07', 0.012182878135647002),
#  ('commonMonthProd_08', 0.031305731507003998),
#  ('commonMonthProd_09', -0.019703968811292327),
#  ('commonMonthProd_10', -0.025114943149990854),
#  ('commonMonthProd_11', 0.00047819953244321312),
#  ('commonMonthProd_12', -0.02850595385574195),
#  ('commonMonth_01', -0.010547239099878425),
#  ('commonMonth_02', -0.016698480136869254),
#  ('commonMonth_03', 0.026013950711047507),
#  ('commonMonth_04', -0.030406427994192242),
#  ('commonMonth_05', -0.011885346328947222),
#  ('commonMonth_06', 0.052362008717978359),
#  ('commonMonth_07', 0.022172227103490982),
#  ('commonMonth_08', 0.0055685352948842137),
#  ('commonMonth_09', -0.013723254483903879),
#  ('commonMonth_10', -0.0058202898640860035),
#  ('commonMonth_11', 0.017012014925955388),
#  ('commonMonth_12', -0.033881064080717671),
#  ('distance_from_july_avgMonthsFromJuly', 0.055921957054792415),
#  ('distance_from_july_avgMonthsFromJuly_prodAgg', 0.0009443910490745111),
#  ('distance_from_july_maxMonthsFromJuly', -0.013725159585014524),
#  ('distance_from_july_maxMonthsFromJuly_prodAgg', 0.0069904299321592589),
#  ('distance_from_july_medianMonthsFromJuly', -0.023520499532281747),
#  ('distance_from_july_medianMonthsFromJuly_prodAgg', 0.0020148343701293925),
#  ('distance_from_july_minMonthsFromJuly', -0.010310808541731831),
#  ('distance_from_july_minMonthsFromJuly_prodAgg', 0.022625875261951478),
#  ('distance_from_july_monthsFromJulyRange', -0.0031378760664324545),
#  ('distance_from_july_monthsFromJulyRange_prodAgg', -0.012763554879136052),
#  ('month_number_of_months', 0.013817038612923136),
#  ('month_number_of_months_prodAgg', -0.04352953125821557),
#  ('month_variety_index', 0.065839024136767677),
#  ('overallSVD', 0.55339183350724852),
#  ('palateSVD', -0.11139295918218295),
#  ('rate_of_posting', -721.17093803771309),
#  ('rate_of_posting_prodAgg', 37534.773449820124),
#  ('review_appearance_appearanceScoreRange', 35.898176331595344),
#  ('review_appearance_appearanceScoreRange_prodAgg', 0.022288035741766521),
#  ('review_appearance_avgAppearanceScore', 0.15410755093092549),
#  ('review_appearance_avgAppearanceScore_prodAgg', 0.090078605078019791),
#  ('review_appearance_maxAppearanceScore', -35.84080674736969),
#  ('review_appearance_maxAppearanceScore_prodAgg', 0.07453844060156456),
#  ('review_appearance_medianAppearanceScore', 0.0094580245853631006),
#  ('review_appearance_medianAppearanceScore_prodAgg', 0.001138315545858859),
#  ('review_appearance_minAppearanceScore', 35.914911998135196),
#  ('review_appearance_minAppearanceScore_prodAgg', 0.052974583450129842),
#  ('review_aroma_aromaScoreRange', -0.0078469675414112317),
#  ('review_aroma_aromaScoreRange_prodAgg', 0.0001597021949351074),
#  ('review_aroma_avgAromaScore', -0.27554820062400154),
#  ('review_aroma_avgAromaScore_prodAgg', 0.028991278608145876),
#  ('review_aroma_maxAromaScore', 0.023831099109984599),
#  ('review_aroma_maxAromaScore_prodAgg', 0.023386678434306418),
#  ('review_aroma_medianAromaScore', 0.011607237279804394),
#  ('review_aroma_medianAromaScore_prodAgg', 0.050349361073102727),
#  ('review_aroma_minAromaScore', 0.031020874574409163),
#  ('review_aroma_minAromaScore_prodAgg', 0.025263995702516695),
#  ('review_overall_avgOverallScore', 0.40041221018554252),
#  ('review_overall_avgOverallScore_prodAgg', 0.062068527341097024),
#  ('review_overall_maxOverallScore', -82.230109504084524),
#  ('review_overall_maxOverallScore_prodAgg', 0.015974463997537214),
#  ('review_overall_medianOverallScore', 0.02615968816451314),
#  ('review_overall_medianOverallScore_prodAgg', 0.07962016297824448),
#  ('review_overall_minOverallScore', 82.215520820068633),
#  ('review_overall_minOverallScore_prodAgg', 0.017682799194545851),
#  ('review_overall_overallScoreRange', 82.226944081351931),
#  ('review_overall_overallScoreRange_prodAgg', 0.01604696123804672),
#  ('review_palate_avgPalateScore', -0.081909835117942587),
#  ('review_palate_avgPalateScore_prodAgg', -0.034640785990035283),
#  ('review_palate_maxPalateScore', -5.0800133085026964),
#  ('review_palate_maxPalateScore_prodAgg', 0.059147527279122869),
#  ('review_palate_medianPalateScore', 0.040165700626399958),
#  ('review_palate_medianPalateScore_prodAgg', 0.046510648141023125),
#  ('review_palate_minPalateScore', 5.1057943623825333),
#  ('review_palate_minPalateScore_prodAgg', 0.057524012729539109),
#  ('review_palate_palateScoreRange', 5.0864660444264338),
#  ('review_palate_palateScoreRange_prodAgg', 0.00074951309228765695),
#  ('review_taste_avgTasteScore', -0.38999897349432522),
#  ('review_taste_avgTasteScore_prodAgg', 0.035080099599255732),
#  ('review_taste_maxTasteScore', 3.0585047222767479),
#  ('review_taste_maxTasteScore_prodAgg', 0.020097527962178674),
#  ('review_taste_medianTasteScore', -0.0037437956578934006),
#  ('review_taste_medianTasteScore_prodAgg', 0.037309583702068494),
#  ('review_taste_minTasteScore', -3.0527437588620217),
#  ('review_taste_minTasteScore_prodAgg', 0.014893756535528269),
#  ('review_taste_tasteScoreRange', -3.0448371298505492),
#  ('review_taste_tasteScoreRange_prodAgg', -0.008909283877613916),
#  ('reviewer_username_user_count', 0.00027940690642935806),
#  ('tasteSVD', 0.49439024875230331),
#  ('time_from_beginning_TimestampRange', 627.42094926907828),
#  ('time_from_beginning_TimestampRange_prodAgg', 2490.2948735791824),
#  ('time_from_beginning_avgTimestamp', 1.7938234231351657e-10),
#  ('time_from_beginning_avgTimestamp_prodAgg', 1.4986198948463425e-09),
#  ('time_from_beginning_maxTimestamp', -627.42094926924563),
#  ('time_from_beginning_maxTimestamp_prodAgg', -2490.2948735790792),
#  ('time_from_beginning_medianTimestamp', -2.7379104539093646e-10),
#  ('time_from_beginning_medianTimestamp_prodAgg', 2.7853275241795927e-10),
#  ('time_from_beginning_minTimestamp', 627.42094926854941),
#  ('time_from_beginning_minTimestamp_prodAgg', 2490.2948735791711),
#  ('vader_neg_avgVaderNeg', 0.52096510409046104),
#  ('vader_neg_avgVaderNeg_prodAgg', 1.2935824867968913),
#  ('vader_neg_maxVaderNeg', 986.08306620453448),
#  ('vader_neg_maxVaderNeg_prodAgg', 0.019197749836212807),
#  ('vader_neg_medianVaderNeg', -0.89062611185171625),
#  ('vader_neg_medianVaderNeg_prodAgg', -0.60390550032357782),
#  ('vader_neg_minVaderNeg', -983.0733948884988),
#  ('vader_neg_minVaderNeg_prodAgg', -0.30086648928115456),
#  ('vader_neg_vaderNegRange', -985.98122531329068),
#  ('vader_neg_vaderNegRange_prodAgg', 0.31962857948596124),
#  ('vader_neu_avgVaderNeu', -0.23678400004211775),
#  ('vader_neu_avgVaderNeu_prodAgg', 0.4852965244504715),
#  ('vader_neu_maxVaderNeu', -0.25291349932428098),
#  ('vader_neu_maxVaderNeu_prodAgg', -0.026587192779219837),
#  ('vader_neu_medianVaderNeu', -0.11783650870228968),
#  ('vader_neu_medianVaderNeu_prodAgg', 0.025075897511869061),
#  ('vader_neu_minVaderNeu', -0.0095078182153409685),
#  ('vader_neu_minVaderNeu_prodAgg', -0.10306187166347947),
#  ('vader_neu_vaderNeuRange', -0.24327525761963287),
#  ('vader_neu_vaderNeuRange_prodAgg', 0.076485377030024893),
#  ('vader_pos_avgVaderPos', 0.012684610910786431),
#  ('vader_pos_avgVaderPos_prodAgg', -2.3028686711602404),
#  ('vader_pos_maxVaderPos', 0.0025386659088235675),
#  ('vader_pos_maxVaderPos_prodAgg', 0.66575931466288374),
#  ('vader_pos_medianVaderPos', -0.078633153358461882),
#  ('vader_pos_medianVaderPos_prodAgg', 0.58589662895062689),
#  ('vader_pos_minVaderPos', -0.042227920569870125),
#  ('vader_pos_minVaderPos_prodAgg', 1.1805179717995355),
#  ('vader_pos_vaderPosRange', 0.0447918635140514),
#  ('vader_pos_vaderPosRange_prodAgg', -0.5151342190422028),
#  ('weekday_central_number_of_weekdays', -0.089034040324864908),
#  ('weekday_central_number_of_weekdays_prodAgg', 0.070918522486628888),
#  ('weekday_variety_index', 0.33083342638984092),
#  ('weekend_review_num_weekend_reviews', -7.6264999421482571e-05),
#  ('weekend_review_num_weekend_reviews_prodAgg', -0.0024037460456867166),
#  ('weekend_review_ratio', -0.023504921615886243),
#  ('weekend_review_ratio_prodAgg', 0.0659308497563309)}

# %% [markdown]
#  Coefficients for various SVD scores
#
#  'overallSVD': 0.55339183350724852
#
#  'palateSVD': -0.11139295918218295
#
#  'tasteSVD': 0.49439024875230331
#
#  'appearanaceSVD': -0.26994564520772002
#
#  'aromaSVD': 0.19297175285295509

# %% [markdown]
# ### Ridge Regression

# %%
ridge=Ridge()

params_grid={"alpha": [0.001, 0.01, 0.1, 1.0, 5.0]}

bestRidge=GridSearchCV(ridge, params_grid, verbose=2, n_jobs=3)

bestRidge.fit(df_train[training_columns],df_train['review_overall'])
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] alpha=0.001 .....................................................
# [CV] alpha=0.001 .....................................................
# [CV] alpha=0.001 .....................................................
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.9527167632547888e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.429976819678099e-19
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.0069694067856814e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [CV] ...................................... alpha=0.001, total= 2.0min
# [CV] alpha=0.01 ......................................................
# [CV] ...................................... alpha=0.001, total= 1.9min
# [CV] alpha=0.01 ......................................................
# [CV] ...................................... alpha=0.001, total= 2.1min
# [CV] alpha=0.01 ......................................................
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.1656076103152866e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.1759924384527157e-19
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.251610951629228e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [CV] ....................................... alpha=0.01, total= 1.2min
# [CV] alpha=0.1 .......................................................
# [CV] ....................................... alpha=0.01, total= 1.0min
# [CV] ....................................... alpha=0.01, total= 1.0min
# [CV] alpha=0.1 .......................................................
# [CV] alpha=0.1 .......................................................
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.0240883307496387e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.9839897671830235e-20
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.3158446030122033e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [CV] ........................................ alpha=0.1, total= 1.1min
# [CV] alpha=1.0 .......................................................
# [CV] ........................................ alpha=0.1, total= 1.1min
# [CV] alpha=1.0 .......................................................
# [CV] ........................................ alpha=0.1, total= 1.1min
# [CV] alpha=1.0 .......................................................
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7575220756807998e-19
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.443222375573847e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.618407748559132e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [CV] ........................................ alpha=1.0, total= 1.1min
# [CV] ........................................ alpha=1.0, total= 1.1min
# [CV] alpha=5.0 .......................................................
# [CV] alpha=5.0 .......................................................
# [CV] ........................................ alpha=1.0, total= 1.2min
# [CV] alpha=5.0 .......................................................
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.6968231795932277e-19
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.650530021061748e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.514214503754671e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [CV] ........................................ alpha=5.0, total=  45.4s
# [CV] ........................................ alpha=5.0, total=  46.7s
# [CV] ........................................ alpha=5.0, total=  46.5s
# [Parallel(n_jobs=3)]: Done  15 out of  15 | elapsed:  7.5min finished
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 5.567991863181092e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params=None, iid=True, n_jobs=3,
#        param_grid={'alpha': [0.001, 0.01, 0.1, 1.0, 5.0]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=2)

# %%
y_test_predRidge = bestRidge.predict(df_test[training_columns])

# %%
mean_absolute_error(df_test['review_overall'], y_test_predRidge)
# Out:
# 1.6132234497743072

# %%
mean_squared_error(df_test['review_overall'], y_test_predRidge)
# Out:
# 4.7864027681386689

# %%
r2_score(df_test['review_overall'], y_test_predRidge)
# Out:
# 0.45012827264350896

# %%
set(zip(df_test[training_columns].columns.values, bestRidge.best_estimator_.coef_))
# Out:
# {('abv', 0.0019417583100838571),
#  ('abv_ABVrange', 0.0054040581278564917),
#  ('abv_ABVrange_prodAgg', 0.0),
#  ('abv_avgABV', -0.19367100524315911),
#  ('abv_avgABV_prodAgg', 0.0019417584233917394),
#  ('abv_listed_num_abv_listed', 0.00014855368592019545),
#  ('abv_listed_num_abv_listed_prodAgg', 0.00052223895265111181),
#  ('abv_maxABV', -0.004558932397691509),
#  ('abv_maxABV_prodAgg', 0.0019417584215964535),
#  ('abv_medianABV', -0.0015222938257510735),
#  ('abv_medianABV_prodAgg', 0.0019417584241683181),
#  ('abv_minABV', -0.0099629886035691156),
#  ('abv_minABV_prodAgg', 0.0019417584332378898),
#  ('appearanaceSVD', -0.26864348659193171),
#  ('aromaSVD', 0.19085392558811454),
#  ('beerID_beerID_count', -0.00011718378306825872),
#  ('beerStyle_ Abbey Dubbel', -0.021986769821188537),
#  ('beerStyle_ Abbey Tripel', -0.054053715471054475),
#  ('beerStyle_ Abt/Quadrupel', -0.10614893156119257),
#  ('beerStyle_ Altbier', -0.0077699164844163265),
#  ('beerStyle_ Amber Ale', -0.047258445648065112),
#  ('beerStyle_ American Dark Lager', -0.033228096236956842),
#  ('beerStyle_ American Pale Ale', -0.016943694973098535),
#  ('beerStyle_ American Strong Ale', -0.0032593295068591311),
#  ('beerStyle_ Baltic Porter', -0.018860583260017365),
#  ('beerStyle_ Barley Wine', -0.0042309432268452535),
#  ('beerStyle_ Belgian Ale', -0.01827589168423133),
#  ('beerStyle_ Belgian Strong Ale', -0.033511385329929443),
#  ('beerStyle_ Belgian White &#40;Witbier&#41;', -0.074908589367771714),
#  ('beerStyle_ Berliner Weisse', 0.045788305850998523),
#  ('beerStyle_ Bitter', -0.13729682269086818),
#  ('beerStyle_ Bière de Garde', -0.045044775751147174),
#  ('beerStyle_ Black IPA', 0.21690958379099518),
#  ('beerStyle_ Bohemian Pilsener', 0.1033756767636234),
#  ('beerStyle_ Brown Ale', 0.014717074829755426),
#  ('beerStyle_ California Common', 0.060882795851789705),
#  ('beerStyle_ Cider', -0.13863406851703014),
#  ('beerStyle_ Classic German Pilsener', -0.042467765799992577),
#  ('beerStyle_ Cream Ale', -0.17238760036166337),
#  ('beerStyle_ Doppelbock', -0.037051932318842809),
#  ('beerStyle_ Dortmunder/Helles', -0.039249865348785745),
#  ('beerStyle_ Dry Stout', 0.008284329782319369),
#  ('beerStyle_ Dunkel', -0.017606776711066186),
#  ('beerStyle_ Dunkelweizen', -0.015824611835307433),
#  ('beerStyle_ Dunkler Bock', 0.019723272932750564),
#  ('beerStyle_ Eisbock', 0.0012427027403707372),
#  ('beerStyle_ English Pale Ale', -0.041417766684218565),
#  ('beerStyle_ English Strong Ale', 0.015169186826395278),
#  ('beerStyle_ Foreign Stout', -0.028684934562809482),
#  ('beerStyle_ Fruit Beer', -0.28170756221815152),
#  ('beerStyle_ German Hefeweizen', -0.074829181159279973),
#  ('beerStyle_ German Kristallweizen', -0.055244416254100509),
#  ('beerStyle_ Golden Ale/Blond Ale', -0.11208614903452398),
#  ('beerStyle_ Heller Bock', 0.079547921375681882),
#  ('beerStyle_ Ice Cider/Perry', 0.24455843381784456),
#  ('beerStyle_ Imperial Stout', -0.00060872529346642245),
#  ('beerStyle_ Imperial/Double IPA', -0.048836080875052694),
#  ('beerStyle_ Imperial/Strong Porter', -0.024423056860756739),
#  ('beerStyle_ India Pale Ale &#40;IPA&#41;', -0.045833321420904335),
#  ('beerStyle_ Irish Ale', -0.073813931542659347),
#  ('beerStyle_ Kölsch', -0.010243297036908058),
#  ('beerStyle_ Lambic - Faro', 0.3776046274655237),
#  ('beerStyle_ Lambic - Fruit', -0.073175538660083431),
#  ('beerStyle_ Lambic - Gueuze', 0.018504350955775083),
#  ('beerStyle_ Lambic - Unblended', 0.24340515125882517),
#  ('beerStyle_ Low Alcohol', -0.44426465256530995),
#  ('beerStyle_ Malt Liquor', -0.22015781456453204),
#  ('beerStyle_ Mead', 0.10852751343061305),
#  ('beerStyle_ Mild Ale', -0.0031807894826821463),
#  ('beerStyle_ Oktoberfest/Märzen', -0.0080528250459134532),
#  ('beerStyle_ Old Ale', 0.018368863445114715),
#  ('beerStyle_ Pale Lager', -0.26048986852569206),
#  ('beerStyle_ Perry', -0.25665751546256727),
#  ('beerStyle_ Pilsener', -0.087322979835423004),
#  ('beerStyle_ Porter', -0.018166453868641193),
#  ('beerStyle_ Premium Bitter/ESB', -0.034747987135096366),
#  ('beerStyle_ Premium Lager', -0.043891728162338869),
#  ('beerStyle_ Saison', 0.080789194696923847),
#  ('beerStyle_ Saké - Daiginjo', 0.61446412468796197),
#  ('beerStyle_ Saké - Futsu-shu', -0.13989927055945844),
#  ('beerStyle_ Saké - Genshu', 0.44116046718507368),
#  ('beerStyle_ Saké - Ginjo', 0.21756088532575624),
#  ('beerStyle_ Saké - Honjozo', 0.33746123954885004),
#  ('beerStyle_ Saké - Infused', -0.6269325800425708),
#  ('beerStyle_ Saké - Junmai', 0.25844069219488941),
#  ('beerStyle_ Saké - Koshu', 0.75421137769893865),
#  ('beerStyle_ Saké - Namasaké', 0.21537507868534489),
#  ('beerStyle_ Saké - Nigori', 0.16740828131796182),
#  ('beerStyle_ Saké - Taru', -0.10355791363651068),
#  ('beerStyle_ Saké - Tokubetsu', -0.37966209969647635),
#  ('beerStyle_ Schwarzbier', 0.047824773396780582),
#  ('beerStyle_ Scotch Ale', -0.049684352346070805),
#  ('beerStyle_ Scottish Ale', 0.025619988431849948),
#  ('beerStyle_ Smoked', 0.051605076991682403),
#  ('beerStyle_ Sour Ale/Wild Ale', 0.13028641362609755),
#  ('beerStyle_ Specialty Grain', 0.00066902692172406955),
#  ('beerStyle_ Spice/Herb/Vegetable', -0.16165135953612628),
#  ('beerStyle_ Stout', -0.018775440857591138),
#  ('beerStyle_ Strong Pale Lager/Imperial Pils', -0.023818680856632291),
#  ('beerStyle_ Sweet Stout', 0.049734659069606675),
#  ('beerStyle_ Traditional Ale', -0.067358235795678664),
#  ('beerStyle_ Vienna', 0.031794477297828153),
#  ('beerStyle_ Weizen Bock', -0.026847414218101124),
#  ('beerStyle_ Wheat Ale', -0.1044900273061464),
#  ('beerStyle_ Zwickel/Keller/Landbier', 0.035498914222291449),
#  ('beerStyle_variety_index', -0.26488875871784207),
#  ('beer_style_numBeerStyles', -0.0054220636964205015),
#  ('beer_variety_index', -0.22294222582978082),
#  ('brewerID_num_brewers', 5.1900477124225967e-05),
#  ('brewer_variety_index', -0.22294222583121423),
#  ('commonDayProd_Friday', 0.0070806959710668247),
#  ('commonDayProd_Monday', 0.0044691403050507329),
#  ('commonDayProd_Saturday', -0.017870634592157538),
#  ('commonDayProd_Sunday', 0.011391466989336423),
#  ('commonDayProd_Thursday', 0.024409453980578349),
#  ('commonDayProd_Tuesday', -0.029077165116577906),
#  ('commonDayProd_Wednesday', -0.00040295742092658895),
#  ('commonDay_Friday', 0.003938424338622586),
#  ('commonDay_Monday', -0.008411048100162407),
#  ('commonDay_Saturday', -0.0025832809902969376),
#  ('commonDay_Sunday', -0.018197083109825214),
#  ('commonDay_Thursday', 0.00071410826911496575),
#  ('commonDay_Tuesday', 0.018977213493219836),
#  ('commonDay_Wednesday', 0.005561666070247372),
#  ('commonMonthProd_01', -0.0028348187926859254),
#  ('commonMonthProd_02', 0.017546799017048965),
#  ('commonMonthProd_03', 0.011078048838257434),
#  ('commonMonthProd_04', 0.017645042807470323),
#  ('commonMonthProd_05', -0.0032848145784708993),
#  ('commonMonthProd_06', 0.018883976799875635),
#  ('commonMonthProd_07', 0.010144323908327401),
#  ('commonMonthProd_08', 0.0099408555154332032),
#  ('commonMonthProd_09', -0.012013628646007593),
#  ('commonMonthProd_10', -0.022233271280436666),
#  ('commonMonthProd_11', -0.010818805811535187),
#  ('commonMonthProd_12', -0.03405370787984538),
#  ('commonMonth_01', -0.012973026437361984),
#  ('commonMonth_02', -0.018270033415582202),
#  ('commonMonth_03', 0.02548899471231237),
#  ('commonMonth_04', -0.024894375705166248),
#  ('commonMonth_05', -0.0095023529709749571),
#  ('commonMonth_06', 0.019392429662304006),
#  ('commonMonth_07', 0.010760973734157745),
#  ('commonMonth_08', 0.0072877894711542027),
#  ('commonMonth_09', 0.0014658511659693051),
#  ('commonMonth_10', -0.0060421707759891865),
#  ('commonMonth_11', 0.012711731326712024),
#  ('commonMonth_12', -0.0054258108164008285),
#  ('distance_from_july_avgMonthsFromJuly', 0.057118269582353852),
#  ('distance_from_july_avgMonthsFromJuly_prodAgg', -0.016178923993834377),
#  ('distance_from_july_maxMonthsFromJuly', -0.012767627209885614),
#  ('distance_from_july_maxMonthsFromJuly_prodAgg', 0.0070873932385704368),
#  ('distance_from_july_medianMonthsFromJuly', -0.026771827812140117),
#  ('distance_from_july_medianMonthsFromJuly_prodAgg', 0.012046385758891505),
#  ('distance_from_july_minMonthsFromJuly', -0.011892394169345673),
#  ('distance_from_july_minMonthsFromJuly_prodAgg', 0.030560699500502955),
#  ('distance_from_july_monthsFromJulyRange', -0.00087523284067807217),
#  ('distance_from_july_monthsFromJulyRange_prodAgg', -0.023473306622937593),
#  ('month_number_of_months', 0.013960640613968825),
#  ('month_number_of_months_prodAgg', -0.041749546734321595),
#  ('month_variety_index', 0.055127461457805955),
#  ('overallSVD', 0.55321595945395452),
#  ('palateSVD', -0.10430021351794382),
#  ('rate_of_posting', -0.017988772150532548),
#  ('rate_of_posting_prodAgg', 0.010596189686399367),
#  ('review_appearance_appearanceScoreRange', -0.0051561405969021588),
#  ('review_appearance_appearanceScoreRange_prodAgg', 0.023928670064418164),
#  ('review_appearance_avgAppearanceScore', 0.15506392284789292),
#  ('review_appearance_avgAppearanceScore_prodAgg', 0.078989897155116146),
#  ('review_appearance_maxAppearanceScore', 0.0011715636057565929),
#  ('review_appearance_maxAppearanceScore_prodAgg', 0.07917554940435248),
#  ('review_appearance_medianAppearanceScore', 0.011546698870140442),
#  ('review_appearance_medianAppearanceScore_prodAgg', 0.0045474094911334695),
#  ('review_appearance_minAppearanceScore', 0.0063277040275888929),
#  ('review_appearance_minAppearanceScore_prodAgg', 0.055246878982987024),
#  ('review_aroma_aromaScoreRange', -0.0075309945534398461),
#  ('review_aroma_aromaScoreRange_prodAgg', 0.0014881802451027887),
#  ('review_aroma_avgAromaScore', -0.27680814458714198),
#  ('review_aroma_avgAromaScore_prodAgg', 0.00069718631472436303),
#  ('review_aroma_maxAromaScore', 0.024816190946408408),
#  ('review_aroma_maxAromaScore_prodAgg', 0.027771083615203244),
#  ('review_aroma_medianAromaScore', 0.01262807269653474),
#  ('review_aroma_medianAromaScore_prodAgg', 0.064915389765656875),
#  ('review_aroma_minAromaScore', 0.032347185683079094),
#  ('review_aroma_minAromaScore_prodAgg', 0.026282903569116788),
#  ('review_overall_avgOverallScore', 0.39024069507940301),
#  ('review_overall_avgOverallScore_prodAgg', 0.081703819856932675),
#  ('review_overall_maxOverallScore', -0.0047160484378401995),
#  ('review_overall_maxOverallScore_prodAgg', 0.019635630293713187),
#  ('review_overall_medianOverallScore', 0.031907037382217777),
#  ('review_overall_medianOverallScore_prodAgg', 0.072492158091843742),
#  ('review_overall_minOverallScore', -0.0073961801497778703),
#  ('review_overall_minOverallScore_prodAgg', 0.0096291219490900869),
#  ('review_overall_overallScoreRange', 0.002680132214954205),
#  ('review_overall_overallScoreRange_prodAgg', 0.010006508998711399),
#  ('review_palate_avgPalateScore', -0.077873544850435142),
#  ('review_palate_avgPalateScore_prodAgg', -0.048035953045351409),
#  ('review_palate_maxPalateScore', -0.0013289494428259821),
#  ('review_palate_maxPalateScore_prodAgg', 0.060653975379015276),
#  ('review_palate_medianPalateScore', 0.041207421665415196),
#  ('review_palate_medianPalateScore_prodAgg', 0.045770465527404956),
#  ('review_palate_minPalateScore', 0.00076039738894516015),
#  ('review_palate_minPalateScore_prodAgg', 0.056603602166707422),
#  ('review_palate_palateScoreRange', -0.0020893469342994357),
#  ('review_palate_palateScoreRange_prodAgg', 0.0040503732133009103),
#  ('review_taste_avgTasteScore', -0.37326761145357845),
#  ('review_taste_avgTasteScore_prodAgg', 0.050726993382566317),
#  ('review_taste_maxTasteScore', 0.011264906576032283),
#  ('review_taste_maxTasteScore_prodAgg', 0.016682439095624588),
#  ('review_taste_medianTasteScore', -0.0089404579238047434),
#  ('review_taste_medianTasteScore_prodAgg', 0.019305746142051432),
#  ('review_taste_minTasteScore', 0.0035265600466896532),
#  ('review_taste_minTasteScore_prodAgg', 0.020215503445426535),
#  ('review_taste_tasteScoreRange', 0.0077383460869290535),
#  ('review_taste_tasteScoreRange_prodAgg', -0.0035330634020008635),
#  ('reviewer_username_user_count', 0.00021082685901698426),
#  ('tasteSVD', 0.4892816331721741),
#  ('time_from_beginning_TimestampRange', 2.1796137958588754e-09),
#  ('time_from_beginning_TimestampRange_prodAgg', -1.3305563947968033e-09),
#  ('time_from_beginning_avgTimestamp', 3.7293147612968344e-10),
#  ('time_from_beginning_avgTimestamp_prodAgg', 1.5399638351701558e-09),
#  ('time_from_beginning_maxTimestamp', -2.3537316814087994e-09),
#  ('time_from_beginning_maxTimestamp_prodAgg', 1.2265261910240842e-09),
#  ('time_from_beginning_medianTimestamp', -4.0803747872573102e-10),
#  ('time_from_beginning_medianTimestamp_prodAgg', 2.7099920109880672e-10),
#  ('time_from_beginning_minTimestamp', 1.5934002209256429e-09),
#  ('time_from_beginning_minTimestamp_prodAgg', -1.0853976889679423e-09),
#  ('vader_neg_avgVaderNeg', 0.50118196692788852),
#  ('vader_neg_avgVaderNeg_prodAgg', 1.3756088699156901),
#  ('vader_neg_maxVaderNeg', 0.98135989619255493),
#  ('vader_neg_maxVaderNeg_prodAgg', 0.036183319417782987),
#  ('vader_neg_medianVaderNeg', -0.85985788478024827),
#  ('vader_neg_medianVaderNeg_prodAgg', -0.54579245873523474),
#  ('vader_neg_minVaderNeg', 1.8545647764194073),
#  ('vader_neg_minVaderNeg_prodAgg', -0.24485141689409506),
#  ('vader_neg_vaderNegRange', -0.87320488025849374),
#  ('vader_neg_vaderNegRange_prodAgg', 0.28103473639143439),
#  ('vader_neu_avgVaderNeu', -0.21710144462555028),
#  ('vader_neu_avgVaderNeu_prodAgg', 0.39864559988382942),
#  ('vader_neu_maxVaderNeu', -0.27001765189490945),
#  ('vader_neu_maxVaderNeu_prodAgg', 0.1315797620500419),
#  ('vader_neu_medianVaderNeu', -0.13114251893679696),
#  ('vader_neu_medianVaderNeu_prodAgg', 0.0076907213436128805),
#  ('vader_neu_minVaderNeu', -0.030128948861567896),
#  ('vader_neu_minVaderNeu_prodAgg', -0.027642914249410126),
#  ('vader_neu_vaderNeuRange', -0.23988870302274246),
#  ('vader_neu_vaderNeuRange_prodAgg', 0.15922267625209399),
#  ('vader_pos_avgVaderPos', 0.019511584829454847),
#  ('vader_pos_avgVaderPos_prodAgg', -2.1902377924829279),
#  ('vader_pos_maxVaderPos', 0.012112795775115573),
#  ('vader_pos_maxVaderPos_prodAgg', 0.62146131367023372),
#  ('vader_pos_medianVaderPos', -0.049166088822110002),
#  ('vader_pos_medianVaderPos_prodAgg', 0.59919209489423053),
#  ('vader_pos_minVaderPos', -0.039197351346501118),
#  ('vader_pos_minVaderPos_prodAgg', 1.1171291046908363),
#  ('vader_pos_vaderPosRange', 0.051310147134587654),
#  ('vader_pos_vaderPosRange_prodAgg', -0.49566779089643259),
#  ('weekday_central_number_of_weekdays', -0.085627900924112613),
#  ('weekday_central_number_of_weekdays_prodAgg', 0.070240828624592244),
#  ('weekday_variety_index', 0.34227132401633475),
#  ('weekend_review_num_weekend_reviews', -7.6146164093873525e-05),
#  ('weekend_review_num_weekend_reviews_prodAgg', -0.0020277614717507551),
#  ('weekend_review_ratio', -0.021671934862151184),
#  ('weekend_review_ratio_prodAgg', 0.03905060540774527)}

# %% [markdown]
# ### Random Forest

# %%
rf=RandomForestRegressor()

param_grid = {"max_depth": [3, 5, None],
              "max_features": [1, 3, 10],
              "min_samples_split": [2, 3, 10],
              "min_samples_leaf": [1, 3, 10]}

bestRF=GridSearchCV(rf, param_grid, verbose=2, n_jobs=3)

bestRF.fit(df_train[training_columns],df_train['review_overall'])
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=3
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=3
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=3, total=  38.8s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=3, total=  35.5s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=3, total=  42.7s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=3, total=  27.7s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=3, total=  29.0s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=3, total=  32.4s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=3, total=  23.7s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=3, total=  31.7s
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=3, total=  31.3s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=3
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=3, total=  28.9s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=3, total=  32.2s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=3, total=  32.3s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=3, total=  35.8s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=3, total=  30.8s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=3, total=  31.2s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=3, total=  36.4s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=3, total=  35.5s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=3, total=  35.4s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=3, total=  42.6s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=3, total=  31.9s
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=3, total=  32.0s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=3
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=3, total=  20.2s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=3, total=  21.2s
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=3, total=  21.2s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=3
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=3, total=  19.2s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=3, total=  19.9s
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=3, total=  20.0s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=3
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=3, total=  19.1s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=3, total=  24.6s
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=3, total=  24.6s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=3
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=3, total=  23.1s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=3, total=  17.4s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=3, total=  17.5s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=3, total=  22.5s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=3, total=  16.8s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=3, total=  17.1s
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:  8.8min
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=3, total=  33.2s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=3, total=  40.0s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=3, total=  44.4s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=3, total=  39.2s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=3, total=  23.8s
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=3, total=  22.2s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=3
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=3, total=  21.4s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=3, total=  16.9s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=3, total=  17.1s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=3, total=  21.5s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=3, total=  17.1s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=3, total=  17.5s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=3, total=  26.1s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=3, total=  21.9s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=3, total=  22.2s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=3, total=  27.0s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=3, total=  21.9s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=3, total=  22.5s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=3, total=  39.7s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=3, total=  35.2s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=3, total=  36.1s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=3, total=  41.3s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=3, total=  34.2s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=3, total=  35.0s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=3, total=  41.8s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=3, total=  35.3s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=3, total=  35.9s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=3, total=  39.6s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=3, total=  37.8s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=3, total=  38.8s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=3, total=  39.5s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=3, total=  33.0s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=3, total=  34.2s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=3, total=  41.4s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=3, total=  33.7s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=3, total=  33.3s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=3, total=  44.4s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=3, total=  35.2s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=3, total=  35.8s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=3, total=  44.3s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=3, total=  39.1s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=3, total=  39.5s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=3
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=3, total=  37.0s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=3, total=  31.8s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=3, total=  31.9s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=5, total=  38.0s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=5, total=  31.5s
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=5, total=  31.4s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=5
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=5, total=  29.4s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=5, total=  27.1s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=5, total=  27.8s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=5, total=  32.8s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=5, total=  28.5s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=5, total=  28.4s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=5, total=  29.8s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=5, total=  27.8s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=5, total=  27.9s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=5, total=  39.8s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=5, total=  35.7s
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=5, total=  34.9s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=5
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=5, total=  37.5s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=5, total=  33.0s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=5, total=  34.3s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=5, total=  35.5s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=5, total=  33.4s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=5, total=  33.4s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=5, total=  38.8s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=5, total=  31.2s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=5, total=  31.6s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=5, total=  36.8s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=5, total=  38.2s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=5, total=  36.0s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=5, total=  38.4s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=5, total=  44.8s
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=5, total=  44.8s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=5
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=5, total=  43.9s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=5, total=  40.1s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=5, total=  44.6s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=5, total=  43.2s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=5, total=  37.5s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=5, total=  41.8s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=5, total=  44.1s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=5, total=  34.2s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=5, total=  34.4s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=5, total=  37.9s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=5, total=  33.4s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=5, total=  37.1s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=5, total=  39.9s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=5, total=  35.1s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=5, total=  34.0s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=5, total=  37.5s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=5, total=  29.1s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=5, total=  29.0s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=5, total=  38.7s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=5, total=  36.4s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=5, total=  36.8s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=5, total=  44.3s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=5, total=  44.4s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=5, total=  46.0s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=5, total=  50.5s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=5, total=  41.5s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=5, total=  42.8s
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=5, total=  44.3s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=5, total=  36.6s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=5, total=  37.8s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=5, total=  46.9s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=5, total=  37.1s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=5, total=  37.7s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=5, total=  46.9s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=5, total=  42.3s
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=5, total=  41.7s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=5
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=5, total=  48.4s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=5, total=  41.5s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=5, total=  42.5s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=5, total=  51.3s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=5, total=  46.8s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=5, total=  46.1s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=5, total=  46.6s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=5, total=  43.4s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=5, total=  46.5s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=5
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed: 44.4min
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=5, total=  57.1s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=5, total=  50.3s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=5, total=  52.6s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=5
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=5, total=  47.4s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=5, total=  40.1s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=5, total=  40.9s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=None, total= 1.2min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=1, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=None, total=  52.9s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=1, max_depth=None, total=  57.3s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=None, total= 1.2min
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=1, max_depth=None, total= 1.2min
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=None, total= 1.2min
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=None, total=  44.6s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=1, max_depth=None, total=  50.5s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=None, total=  50.2s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=None, total=  37.2s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=1, max_depth=None, total=  49.1s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=None, total=  45.1s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=None, total=  43.5s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=1, max_depth=None, total=  42.2s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=None, total=  33.6s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=None, total=  37.2s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=1, max_depth=None, total=  37.7s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=None, total=  40.6s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=None, total=  39.5s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=1, max_depth=None, total=  40.2s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=None, total=  40.5s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=None, total=  40.7s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=1, max_depth=None, total=  41.8s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=None, total= 1.0min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=3, max_depth=None, total= 1.0min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=None, total= 1.0min
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=None, total=  59.9s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=3, max_depth=None, total=  57.0s
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=None, total=  52.3s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=None, total=  50.0s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=3, max_depth=None, total=  45.1s
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=None, total=  53.9s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=None, total=  47.9s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=3, max_depth=None, total=  48.2s
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=None, total=  51.3s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=None, total=  50.2s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=3, max_depth=None, total=  52.6s
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=None, total=  51.4s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=None, total=  51.2s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=3, max_depth=None, total=  55.3s
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=None, total=  58.4s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=None, total=  51.9s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=3, max_depth=None, total=  48.3s
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=None, total=  55.0s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=None, total=  43.9s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=3, max_depth=None, total=  45.6s
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=None, total=  48.2s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=None, total=  39.5s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=3, max_depth=None, total=  39.7s
# [CV] min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=None, total= 1.7min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=None, total= 1.6min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=2, max_features=10, max_depth=None, total= 1.6min
# [CV] min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=None, total= 1.6min
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=None, total= 1.5min
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=3, max_features=10, max_depth=None, total= 1.5min
# [CV] min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=None, total= 1.5min
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=None, total= 1.4min
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=1, min_samples_split=10, max_features=10, max_depth=None, total= 1.4min
# [CV] min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=None, total= 1.4min
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=None, total= 1.3min
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=2, max_features=10, max_depth=None, total= 1.4min
# [CV] min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=None, total= 1.6min
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=None, total= 1.5min
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=3, max_features=10, max_depth=None, total= 1.6min
# [CV] min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=None, total= 1.3min
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=None, total= 1.3min
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=3, min_samples_split=10, max_features=10, max_depth=None, total= 1.3min
# [CV] min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=2, max_features=10, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=None, total= 1.2min
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=None, total= 1.1min
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=3, max_features=10, max_depth=None, total= 1.2min
# [CV] min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=None
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=None, total= 1.1min
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=None, total= 1.1min
# [CV]  min_samples_leaf=10, min_samples_split=10, max_features=10, max_depth=None, total= 1.1min
# [Parallel(n_jobs=3)]: Done 243 out of 243 | elapsed: 84.3min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=3,
#        param_grid={'min_samples_split': [2, 3, 10], 'min_samples_leaf': [1, 3, 10], 'max_features': [1, 3, 10], 'max_depth': [3, 5, None]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=2)

# %%
pickle.dump(bestRF, open('./rf_model.pkl', 'wb'))

# %%
y_test_predRF = bestRF.predict(df_test[training_columns])

# %%
mean_absolute_error(df_test['review_overall'], y_test_predRF)
# Out:
# 1.5212611967947476

# %%
mean_squared_error(df_test['review_overall'], y_test_predRF)
# Out:
# 4.360343037270562

# %%
r2_score(df_test['review_overall'], y_test_predRF)
# Out:
# 0.49907488485278473

# %% [markdown]
# ### XGBoost

# %% [markdown]
# Took about 45 minutes and still hadn't finished running a single run. 4 runs can be done at a time but that needs there are 60 fits in total to do just to fit the first 2 hyperparameters. I'm going to leave xgboost for the moment.

# %%
param_test1 = {
 'max_depth':range(3,10,2),
 'min_child_weight':range(1,6,2)
}
gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=100, max_depth=5,
 min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'reg:linear', nthread=4, scale_pos_weight=1, seed=27), 
 param_grid = param_test1, scoring='roc_auc',n_jobs=4,iid=False, cv=5, verbose=2)
gsearch1.fit(df_train[training_columns],df_train['review_overall'])
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] min_child_weight=1, max_depth=3 .................................
# [CV] min_child_weight=1, max_depth=3 .................................
# [CV] min_child_weight=1, max_depth=3 .................................
# [CV] min_child_weight=1, max_depth=3 .................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-ba5dee79757a> in <module>()
#       7  objective= 'reg:linear', nthread=4, scale_pos_weight=1, seed=27),
#       8  param_grid = param_test1, scoring='roc_auc',n_jobs=4,iid=False, cv=5, verbose=2)
# ----> 9 gsearch1.fit(df_train[training_columns],df_train['review_overall'])
#      10 gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     636                                   error_score=self.error_score)
#     637           for parameters, (train, test) in product(candidate_params,
# --> 638                                                    cv.split(X, y, groups)))
#     639
#     640         # if one choose to see train score, "out" will contain train score info
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# ~/anaconda2/envs/py35/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda2/envs/py35/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda2/envs/py35/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# ~/anaconda2/envs/py35/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:
