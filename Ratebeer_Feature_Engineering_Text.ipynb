# %% [markdown]
# # Ratebeer Text Feature Engineering

# %%
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
import fasttext
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from surprise import SVD
from surprise import Dataset
from surprise import evaluate, print_perf, Reader, dump
from sklearn.model_selection import train_test_split
import os

# %%
df = pd.read_pickle('./train_set.pkl')

# %%
df.head()
# Out:
#          beerID                                  beer_name  abv  abv_listed  \
# 367332     5868                      St Peters Organic Ale  4.5        True
# 1841875     493                                Busch Light  4.1        True
# 1420827   85344                     Auburn Alehouse Red 45  6.0        True
# 1709329    1763   Greene King Abbot Ale &#40;Filtered&#41;  5.0        True
# 327581     2396                       Atlantic Coal Porter  5.8        True
#
#          brewerID           beer_style reviewer_username  review_appearance  \
# 367332        974               Bitter        abemorsten                  3
# 1841875        84           Pale Lager    beerdrinker101                  1
# 1420827      8572            Irish Ale                bb                  4
# 1709329       143   Premium Bitter/ESB            jazz88                  4
# 327581        253               Porter          zach8270                  3
#
#          review_aroma  review_palate             ...               vader_pos  \
# 367332              6              4             ...                   0.179
# 1841875             1              1             ...                   0.100
# 1420827             7              3             ...                   0.000
# 1709329             5              3             ...                   0.107
# 327581              6              4             ...                   0.000
#
#          time_from_beginning weekend_review  \
# 367332             300412800           True
# 1841875            186105600           True
# 1420827            250473600          False
# 1709329             94867200          False
# 327581             141004800          False
#
#                 time_from_beginning_lookup          weekday_central_lookup  \
# 367332      [5868,  abemorsten, 300412800]     [5868,  abemorsten, Sunday]
# 1841875  [493,  beerdrinker101, 186105600]  [493,  beerdrinker101, Sunday]
# 1420827            [85344,  bb, 250473600]         [85344,  bb, Wednesday]
# 1709329          [1763,  jazz88, 94867200]         [1763,  jazz88, Monday]
# 327581        [2396,  zach8270, 141004800]    [2396,  zach8270, Wednesday]
#
#                        month_lookup  distance_from_july_lookup  \
# 367332      [5868,  abemorsten, 10]     [5868,  abemorsten, 3]
# 1841875  [493,  beerdrinker101, 03]  [493,  beerdrinker101, 4]
# 1420827            [85344,  bb, 03]            [85344,  bb, 4]
# 1709329         [1763,  jazz88, 04]         [1763,  jazz88, 3]
# 327581        [2396,  zach8270, 09]       [2396,  zach8270, 2]
#
#                     vader_neg_lookup             vader_neu_lookup  \
# 367332    [5868,  abemorsten, 0.064]   [5868,  abemorsten, 0.757]
# 1841875  [493,  beerdrinker101, 0.0]  [493,  beerdrinker101, 0.9]
# 1420827            [85344,  bb, 0.0]            [85344,  bb, 1.0]
# 1709329       [1763,  jazz88, 0.128]       [1763,  jazz88, 0.764]
# 327581      [2396,  zach8270, 0.062]     [2396,  zach8270, 0.938]
#
#                     vader_pos_lookup
# 367332    [5868,  abemorsten, 0.179]
# 1841875  [493,  beerdrinker101, 0.1]
# 1420827            [85344,  bb, 0.0]
# 1709329       [1763,  jazz88, 0.107]
# 327581        [2396,  zach8270, 0.0]
#
# [5 rows x 42 columns]

# %%
stopWords = set(stopwords.words('english'))

# %%
df['text_filtered'] = df['review_text']\
.apply( lambda x: " ".join([i for i in x.lower().split() if i not in stopWords]) )

# %%
# now remove punctuation
df["text_simple"] = df['text_filtered'].str.replace('[^\w\s]','')

# %%
#sentiment_scorer = SentimentIntensityAnalyzer()
#df['sentiment_vader'] = df['review_text'].apply(lambda x: sentiment_scorer.polarity_scores(x))
#df1, df2 = np.array_split(df, 2)
#df1.to_pickle(path='./post_vader1.pkl')
#df2.to_pickle(path='./post_vader2.pkl')

df1 = pd.read_pickle('post_vader1.pkl')
df2 = pd.read_pickle('post_vader2.pkl')
df=pd.concat([df1,df2])

# %%
df.columns.values
# Out:
# array(['beerID', 'beer_name', 'abv', 'abv_listed', 'brewerID',
#        'beer_style', 'reviewer_username', 'review_appearance',
#        'review_aroma', 'review_palate', 'review_taste', 'review_overall',
#        'review_text', 'review_unix_time', 'weekday_central', 'day_of_year',
#        'month', 'distance_from_july', 'text_filtered', 'text_simple',
#        'sentiment_vader'], dtype=object)

# %%
df.head()
# Out:
#          beerID                  beer_name  abv  abv_listed  brewerID  \
# 2291588     121      Stone City Hefeweizen  6.0       False        23
# 1651460     132        Newcastle Brown Ale  4.7        True       751
# 2146614     286   Worthington White Shield  5.6        True     12871
# 2182000     544           Saranac Pale Ale  5.5        True        92
# 2171356     547      Saranac Black and Tan  5.1        True        92
#
#                   beer_style reviewer_username  review_appearance  \
# 2291588    German Hefeweizen         lazarus99                  5
# 1651460            Brown Ale             billb                  5
# 2146614   Premium Bitter/ESB              wade                  3
# 2182000     English Pale Ale             billb                  4
# 2171356                Stout             billb                  3
#
#          review_aroma  review_palate  \
# 2291588             8              4
# 1651460             6              5
# 2146614            10              4
# 2182000             7              5
# 2171356             7              2
#
#                                ...                          review_overall  \
# 2291588                        ...                                      20
# 1651460                        ...                                      17
# 2146614                        ...                                      18
# 2182000                        ...                                      17
# 2171356                        ...                                      10
#
#                                                review_text review_unix_time  \
# 2291588   I love this kind of beer. It seems to be the ...        955497600
# 1651460   This has to be one of my favorite drinking be...        955497600
# 2146614   Excellent ale with a strong aroma and initial...        955843200
# 2182000   Pretty tasty for a pale ale.  This is one of ...        956448000
# 2171356   I a big fan of Black and Tans but this one is...        956448000
#
#          weekday_central day_of_year  month distance_from_july  \
# 2291588          Tuesday         102     04                  3
# 1651460          Tuesday         102     04                  3
# 2146614         Saturday         106     04                  3
# 2182000         Saturday         113     04                  3
# 2171356         Saturday         113     04                  3
#
#                                              text_filtered  \
# 2291588  love kind beer. seems thing apart corona type ...
# 1651460  one favorite drinking beers. light, dark. good...
# 2146614  excellent ale strong aroma initial flavor. aft...
# 2182000  pretty tasty pale ale. one faves saranac. nice...
# 2171356  big fan black tans one rather disappointing. a...
#
#                                                text_simple  \
# 2291588  love kind beer seems thing apart corona type b...
# 1651460  one favorite drinking beers light dark good cl...
# 2146614  excellent ale strong aroma initial flavor afte...
# 2182000  pretty tasty pale ale one faves saranac nice h...
# 2171356  big fan black tans one rather disappointing ar...
#
#                                            sentiment_vader
# 2291588  {'neu': 0.819, 'compound': 0.6369, 'pos': 0.18...
# 1651460  {'neu': 0.798, 'compound': 0.8225, 'pos': 0.20...
# 2146614  {'neu': 0.568, 'compound': 0.81, 'pos': 0.432,...
# 2182000  {'neu': 0.691, 'compound': 0.8807, 'pos': 0.30...
# 2171356  {'neu': 0.701, 'compound': 0.0516, 'pos': 0.16...
#
# [5 rows x 21 columns]

# %%
# split vader sentiment scores into seperate columns
df['vader_neg']=df['sentiment_vader'].apply(lambda x: float(x['neg']))
df['vader_neu']=df['sentiment_vader'].apply(lambda x: float(x['neu']))
df['vader_pos']=df['sentiment_vader'].apply(lambda x: float(x['pos']))

# %% [markdown]
# Create a feature listing number of seconds since first review on record. This might be easier to train on than the unix time value.

# %%
df['review_unix_time'].min()
# Out:
# 955497600

# %%
df['time_from_beginning']=df['review_unix_time']-955497600

# %%
# create boolean feature saying if review is on weekend
df['weekend_review']=df['weekday_central'].apply(lambda x: True if x in ['Friday', 'Saturday', 'Sunday'] else False)

# %%
# create this list of lists so we can aggregate into a dict later 
# This approach is stupid! Ended up running out of memory or it became too computationally expensive
"""df['text_lookup'] = df[['beerID','reviewer_username', 'text_simple']].values.tolist()
df['abv_lookup']=df[['beerID', 'reviewer_username', 'abv']].values.tolist()
df['brewerID_lookup']=df[['beerID','reviewer_username','brewerID']].values.tolist()
df['beerStyle_lookup']=df[['beerID','reviewer_username','beer_style']].values.tolist()
df['review_appearance_lookup']=df[['beerID','reviewer_username','review_appearance']].values.tolist()
df['review_aroma_lookup']=df[['beerID', 'reviewer_username', 'review_aroma']].values.tolist()
df['review_palate_lookup']=df[['beerID', 'reviewer_username', 'review_palate']].values.tolist()
df['review_taste_lookup']=df[['beerID', 'reviewer_username', 'review_taste']].values.tolist()
df['review_overall_lookup']=df[['beerID', 'reviewer_username', 'review_overall']].values.tolist()
df['time_from_beginning_lookup']=df[['beerID', 'reviewer_username', 'time_from_beginning']].values.tolist()
df['weekday_central_lookup']=df[['beerID', 'reviewer_username', 'weekday_central']].values.tolist()
df['month_lookup']=df[['beerID', 'reviewer_username', 'month']].values.tolist()
df['distance_from_july_lookup']=df[['beerID', 'reviewer_username', 'distance_from_july']].values.tolist()
df['vader_neg_lookup']=df[['beerID', 'reviewer_username', 'vader_neg']].values.tolist()
df['vader_neu_lookup']=df[['beerID', 'reviewer_username', 'vader_neu']].values.tolist()
df['vader_pos_lookup']=df[['beerID', 'reviewer_username', 'vader_pos']].values.tolist()"""
# Out:
# "df['text_lookup'] = df[['beerID','reviewer_username', 'text_simple']].values.tolist()\ndf['abv_lookup']=df[['beerID', 'reviewer_username', 'abv']].values.tolist()\ndf['brewerID_lookup']=df[['beerID','reviewer_username','brewerID']].values.tolist()\ndf['beerStyle_lookup']=df[['beerID','reviewer_username','beer_style']].values.tolist()\ndf['review_appearance_lookup']=df[['beerID','reviewer_username','review_appearance']].values.tolist()\ndf['review_aroma_lookup']=df[['beerID', 'reviewer_username', 'review_aroma']].values.tolist()\ndf['review_palate_lookup']=df[['beerID', 'reviewer_username', 'review_palate']].values.tolist()\ndf['review_taste_lookup']=df[['beerID', 'reviewer_username', 'review_taste']].values.tolist()\ndf['review_overall_lookup']=df[['beerID', 'reviewer_username', 'review_overall']].values.tolist()\ndf['time_from_beginning_lookup']=df[['beerID', 'reviewer_username', 'time_from_beginning']].values.tolist()\ndf['weekday_central_lookup']=df[['beerID', 'reviewer_username', 'weekday_central']].values.tolist()\ndf['month_lookup']=df[['beerID', 'reviewer_username', 'month']].values.tolist()\ndf['distance_from_july_lookup']=df[['beerID', 'reviewer_username', 'distance_from_july']].values.tolist()\ndf['vader_neg_lookup']=df[['beerID', 'reviewer_username', 'vader_neg']].values.tolist()\ndf['vader_neu_lookup']=df[['beerID', 'reviewer_username', 'vader_neu']].values.tolist()\ndf['vader_pos_lookup']=df[['beerID', 'reviewer_username', 'vader_pos']].values.tolist()"

# %%
df.columns.values
# Out:
# array(['beerID', 'beer_name', 'abv', 'abv_listed', 'brewerID',
#        'beer_style', 'reviewer_username', 'review_appearance',
#        'review_aroma', 'review_palate', 'review_taste', 'review_overall',
#        'review_text', 'review_unix_time', 'weekday_central', 'day_of_year',
#        'month', 'distance_from_july', 'text_filtered', 'text_simple',
#        'sentiment_vader', 'vader_neg', 'vader_neu', 'vader_pos',
#        'time_from_beginning', 'weekend_review'], dtype=object)

# %% [markdown]
# ## Aggregate features

# %% [markdown]
# ### Aggregate by User

# %%
# below old version of aggregation before I realised I would need to keep tab of which review corresponds to which 
# value so I could adjust the aggregate values by removing the values corresponding to a specific item/reviewer
# when we join later
"""aggregation={
    'beerID' : {
        'beerID_count' : 'count'
    },
    'abv' : {
        'avgABV' : 'mean',
        'medianABV' : 'median',
        'maxABV' : 'max',
        'minABV' : 'min',
        'ABVrange' : lambda x: max(x) - min(x)
    },
    'abv_listed' : {
        'num_abv_listed' : lambda x: int(sum(x)) 
    },
    'brewerID' : {
        'num_brewers' : lambda x: x.nunique()
    },
    'beer_style' : {
        'numBeerStyles' : lambda x : x.nunique()
    },
    'review_appearance' : {
        'avgAppearanceScore' : 'mean',
        'medianAppearanceScore' : 'median',
        'maxAppearanceScore' : 'max',
        'minAppearanceScore' : 'min',
        'appearanceScoreRange' : lambda x: max(x) - min(x)
    },
    'review_aroma' : {
        'avgAromaScore' : 'mean',
        'medianAromaScore' : 'median',
        'maxAromaScore' : 'max',
        'minAromaScore' : 'min',
        'aromaScoreRange' : lambda x: max(x) - min(x)
    },
    'review_palate' : {
        'avgPalateScore' : 'mean',
        'medianPalateScore' : 'median',
        'maxPalateScore' : 'max',
        'minPalateScore' : 'min',
        'palateScoreRange' : lambda x: max(x) - min(x)
    },
    'review_taste' : {
        'avgTasteScore' : 'mean',
        'medianTasteScore' : 'median',
        'maxTasteScore' : 'max',
        'minTasteScore' : 'min',
        'tasteScoreRange' : lambda x: max(x) - min(x)
    },
    'review_overall' : {
        'avgOverallScore' : 'mean',
        'medianOverallScore' : 'median',
        'maxOverallScore' : 'max',
        'minOverallScore' : 'min',
        'overallScoreRange' : lambda x: max(x) - min(x)
    },
    'text_lookup' : {
        'text_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'time_from_beginning' : {
        'avgTimestamp' : 'mean',
        'medianTimestamp' : 'median',
        'maxTimestamp' : 'max',
        'minTimestamp' : 'min',
        'TimestampRange' : lambda x: max(x) - min(x)
    },
    'weekday_central' : {
        'most_common_weekday' : lambda x: x.value_counts().index[0],
        'number_of_weekdays' : lambda x: x.nunique()
    },
    'weekend_review' : {
        'num_weekend_reviews' : 'sum'
    },
    'month' : {
        'most_common_month' : lambda x: x.value_counts().index[0],
        'number_of_months' : lambda x: x.nunique()
    },
    'distance_from_july' : {
        'avgMonthsFromJuly' : 'mean',
        'medianMonthsFromJuly' : 'median',
        'maxMonthsFromJuly' : 'max',
        'minMonthsFromJuly' : 'min',
        'monthsFromJulyRange' : lambda x: max(x) - min(x)
    },
    'vader_neg' : {
        'avgVaderNeg' : 'mean',
        'medianVaderNeg' : 'median',
        'maxVaderNeg' : 'max',
        'minVaderNeg' : 'min',
        'vaderNegRange' : lambda x: max(x) - min(x)
    },
    'vader_neu' : {
        'avgVaderNeu' : 'mean',
        'medianVaderNeu' : 'median',
        'maxVaderNeu' : 'max',
        'minVaderNeu' : 'min',
        'vaderNeuRange' : lambda x: max(x) - min(x)
    },
    'vader_pos' : {
        'avgVaderPos' : 'mean',
        'medianVaderPos' : 'median',
        'maxVaderPos' : 'max',
        'minVaderPos' : 'min',
        'vaderPosRange' : lambda x: max(x) - min(x)
    }
}
aggByUser_df = df.groupby('reviewer_username').agg(aggregation)"""
# Out:
# "aggregation={\n    'beerID' : {\n        'beerID_count' : 'count'\n    },\n    'abv' : {\n        'avgABV' : 'mean',\n        'medianABV' : 'median',\n        'maxABV' : 'max',\n        'minABV' : 'min',\n        'ABVrange' : lambda x: max(x) - min(x)\n    },\n    'abv_listed' : {\n        'num_abv_listed' : lambda x: int(sum(x)) \n    },\n    'brewerID' : {\n        'num_brewers' : lambda x: x.nunique()\n    },\n    'beer_style' : {\n        'numBeerStyles' : lambda x : x.nunique()\n    },\n    'review_appearance' : {\n        'avgAppearanceScore' : 'mean',\n        'medianAppearanceScore' : 'median',\n        'maxAppearanceScore' : 'max',\n        'minAppearanceScore' : 'min',\n        'appearanceScoreRange' : lambda x: max(x) - min(x)\n    },\n    'review_aroma' : {\n        'avgAromaScore' : 'mean',\n        'medianAromaScore' : 'median',\n        'maxAromaScore' : 'max',\n        'minAromaScore' : 'min',\n        'aromaScoreRange' : lambda x: max(x) - min(x)\n    },\n    'review_palate' : {\n        'avgPalateScore' : 'mean',\n        'medianPalateScore' : 'median',\n        'maxPalateScore' : 'max',\n        'minPalateScore' : 'min',\n        'palateScoreRange' : lambda x: max(x) - min(x)\n    },\n    'review_taste' : {\n        'avgTasteScore' : 'mean',\n        'medianTasteScore' : 'median',\n        'maxTasteScore' : 'max',\n        'minTasteScore' : 'min',\n        'tasteScoreRange' : lambda x: max(x) - min(x)\n    },\n    'review_overall' : {\n        'avgOverallScore' : 'mean',\n        'medianOverallScore' : 'median',\n        'maxOverallScore' : 'max',\n        'minOverallScore' : 'min',\n        'overallScoreRange' : lambda x: max(x) - min(x)\n    },\n    'text_lookup' : {\n        'text_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'time_from_beginning' : {\n        'avgTimestamp' : 'mean',\n        'medianTimestamp' : 'median',\n        'maxTimestamp' : 'max',\n        'minTimestamp' : 'min',\n        'TimestampRange' : lambda x: max(x) - min(x)\n    },\n    'weekday_central' : {\n        'most_common_weekday' : lambda x: x.value_counts().index[0],\n        'number_of_weekdays' : lambda x: x.nunique()\n    },\n    'weekend_review' : {\n        'num_weekend_reviews' : 'sum'\n    },\n    'month' : {\n        'most_common_month' : lambda x: x.value_counts().index[0],\n        'number_of_months' : lambda x: x.nunique()\n    },\n    'distance_from_july' : {\n        'avgMonthsFromJuly' : 'mean',\n        'medianMonthsFromJuly' : 'median',\n        'maxMonthsFromJuly' : 'max',\n        'minMonthsFromJuly' : 'min',\n        'monthsFromJulyRange' : lambda x: max(x) - min(x)\n    },\n    'vader_neg' : {\n        'avgVaderNeg' : 'mean',\n        'medianVaderNeg' : 'median',\n        'maxVaderNeg' : 'max',\n        'minVaderNeg' : 'min',\n        'vaderNegRange' : lambda x: max(x) - min(x)\n    },\n    'vader_neu' : {\n        'avgVaderNeu' : 'mean',\n        'medianVaderNeu' : 'median',\n        'maxVaderNeu' : 'max',\n        'minVaderNeu' : 'min',\n        'vaderNeuRange' : lambda x: max(x) - min(x)\n    },\n    'vader_pos' : {\n        'avgVaderPos' : 'mean',\n        'medianVaderPos' : 'median',\n        'maxVaderPos' : 'max',\n        'minVaderPos' : 'min',\n        'vaderPosRange' : lambda x: max(x) - min(x)\n    }\n}\naggByUser_df = df.groupby('reviewer_username').agg(aggregation)"

# %%
# See above. This approach, of keeping aggregate features in lists was way too computationally expensive
"""aggregation={
    'beerID' : {
        'beerID_count' : 'count'
    },
    'abv_lookup' : {
        'abv_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'abv_listed' : {
        'num_abv_listed' : lambda x: int(sum(x)) 
    },
    'brewerID_lookup' : {
        'brewerID_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'beerStyle_lookup' : {
        'beerStyle_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'review_appearance_lookup' : {
        'reviewAppearance_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'review_aroma_lookup' : {
        'reviewAroma_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'review_palate_lookup' : {
        'reviewPalate_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'review_taste_lookup' : {
        'reviewTaste_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'review_overall_lookup' : {
        'reviewOverall_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'text_lookup' : {
        'text_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'time_from_beginning_lookup' : {
        'time_from_beginning_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'weekday_central_lookup' : {
        'weekday_central_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'weekend_review' : {
        'num_weekend_reviews' : 'sum'
    },
    'month_lookup' : {
        'month_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'distance_from_july_lookup' : {
        'distance_from_july_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'vader_neg_lookup' : {
        'vader_neg_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'vader_neu_lookup' : {
        'vader_neu_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'vader_pos_lookup' : {
        'vader_pos_list' : lambda x : [[item[0],item[2]] for item in x]
    }
}
aggByUser_df = df.groupby('reviewer_username').agg(aggregation)"""
# Out:
# "aggregation={\n    'beerID' : {\n        'beerID_count' : 'count'\n    },\n    'abv_lookup' : {\n        'abv_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'abv_listed' : {\n        'num_abv_listed' : lambda x: int(sum(x)) \n    },\n    'brewerID_lookup' : {\n        'brewerID_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'beerStyle_lookup' : {\n        'beerStyle_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'review_appearance_lookup' : {\n        'reviewAppearance_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'review_aroma_lookup' : {\n        'reviewAroma_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'review_palate_lookup' : {\n        'reviewPalate_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'review_taste_lookup' : {\n        'reviewTaste_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'review_overall_lookup' : {\n        'reviewOverall_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'text_lookup' : {\n        'text_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'time_from_beginning_lookup' : {\n        'time_from_beginning_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'weekday_central_lookup' : {\n        'weekday_central_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'weekend_review' : {\n        'num_weekend_reviews' : 'sum'\n    },\n    'month_lookup' : {\n        'month_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'distance_from_july_lookup' : {\n        'distance_from_july_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'vader_neg_lookup' : {\n        'vader_neg_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'vader_neu_lookup' : {\n        'vader_neu_list' : lambda x : [[item[0],item[2]] for item in x]\n    },\n    'vader_pos_lookup' : {\n        'vader_pos_list' : lambda x : [[item[0],item[2]] for item in x]\n    }\n}\naggByUser_df = df.groupby('reviewer_username').agg(aggregation)"

# %%
#aggByUser_df['text_dict'] = aggByUser_df['text_lookup']['text_list'].apply(lambda x: {item[0]:item[1] for item in x})

#test=aggByUser_df['text_lookup']['text_dict'][4]
#{x[0]:x[1] for x in test}

# %%
#aggByUser_df.columns = aggByUser_df.columns.droplevel()

# %%
#aggByUser_df.head()

# %%
#aggByUser_df['weekend_review']

# %%
#aggByUser_df['beerID_count'].head()

# %%
#aggByUser_df['beerID_count'].mean()

# %%
"""aggregation2={
    'reviewer_username' : {
        'user_count' : 'count'
    },
    'abv' : {
        'ABV' : lambda x: x.value_counts().index[0]
    },
    'abv_listed' : {
        'num_abv_listed' : lambda x: x.value_counts().index[0]
    },
    'brewerID' : {
        'num_brewers' : lambda x: x.value_counts().index[0]
    },
    'beer_style' : {
        'numBeerStyles' : lambda x: x.value_counts().index[0]
    },
    'review_appearance_lookup' : {
        'reviewAppearance_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'review_aroma_lookup' : {
        'reviewAroma_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'review_palate_lookup' : {
        'reviewPalate_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'review_taste_lookup' : {
        'reviewTaste_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'review_overall_lookup' : {
        'reviewOverall_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'text_lookup' : {
        'text_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'time_from_beginning_lookup' : {
        'time_from_beginning_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'weekday_central_lookup' : {
        'weekday_central_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'weekend_review' : {
        'num_weekend_reviews' : 'sum'
    },
    'month_lookup' : {
        'month_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'distance_from_july_lookup' : {
        'distance_from_july_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'vader_neg_lookup' : {
        'vader_neg_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'vader_neu_lookup' : {
        'vader_neu_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'vader_pos_lookup' : {
        'vader_pos_list' : lambda x : [[item[1],item[2]] for item in x]
    }
}
aggByProduct_df = df.groupby('beerID').agg(aggregation2)"""
# Out:
# "aggregation2={\n    'reviewer_username' : {\n        'user_count' : 'count'\n    },\n    'abv' : {\n        'ABV' : lambda x: x.value_counts().index[0]\n    },\n    'abv_listed' : {\n        'num_abv_listed' : lambda x: x.value_counts().index[0]\n    },\n    'brewerID' : {\n        'num_brewers' : lambda x: x.value_counts().index[0]\n    },\n    'beer_style' : {\n        'numBeerStyles' : lambda x: x.value_counts().index[0]\n    },\n    'review_appearance_lookup' : {\n        'reviewAppearance_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'review_aroma_lookup' : {\n        'reviewAroma_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'review_palate_lookup' : {\n        'reviewPalate_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'review_taste_lookup' : {\n        'reviewTaste_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'review_overall_lookup' : {\n        'reviewOverall_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'text_lookup' : {\n        'text_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'time_from_beginning_lookup' : {\n        'time_from_beginning_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'weekday_central_lookup' : {\n        'weekday_central_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'weekend_review' : {\n        'num_weekend_reviews' : 'sum'\n    },\n    'month_lookup' : {\n        'month_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'distance_from_july_lookup' : {\n        'distance_from_july_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'vader_neg_lookup' : {\n        'vader_neg_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'vader_neu_lookup' : {\n        'vader_neu_list' : lambda x : [[item[1],item[2]] for item in x]\n    },\n    'vader_pos_lookup' : {\n        'vader_pos_list' : lambda x : [[item[1],item[2]] for item in x]\n    }\n}\naggByProduct_df = df.groupby('beerID').agg(aggregation2)"

# %%
# Thia will now have to waint until aggretation from all the list features is done
# rate of reviewing - beerID_count/timeStampRange
#aggByProduct_df['rate_of_posting'] = aggByProduct_df['reviewer_username']['user_count']/aggByProduct_df['time_from_beginning']['TimestampRange']

# weekday variety index - number_of_weekdays/beerID_count
#aggByProduct_df['weekday_variety_index'] = aggByProduct_df['weekday_central']['number_of_weekdays']/aggByProduct_df['reviewer_username']['user_count']

# month variety index - number_of_months/beerID_count
#aggByProduct_df['month_variety_index'] = aggByProduct_df['month']['number_of_months']/aggByProduct_df['reviewer_username']['user_count']

# weekend review ratio - num_weekend_reviews/beerID_count
#aggByProduct_df['weekend_review_ratio'] = aggByProduct_df['weekend_review']['num_weekend_reviews']/aggByProduct_df['reviewer_username']['user_count']

# %%
#aggByProduct_df.columns = aggByProduct_df.columns.droplevel()

# %%
#aggByProduct_df.head()

# %%
#aggByProduct_df['reviewer_username'].mean()

# %% [markdown]
# ## Collaborative filtering features

# %%
df.columns
# Out:
# Index(['beerID', 'beer_name', 'abv', 'abv_listed', 'brewerID', 'beer_style',
#        'reviewer_username', 'review_appearance', 'review_aroma',
#        'review_palate', 'review_taste', 'review_overall', 'review_text',
#        'review_unix_time', 'weekday_central', 'day_of_year', 'month',
#        'distance_from_july', 'text_filtered', 'text_simple', 'sentiment_vader',
#        'text_lookup', 'abv_lookup', 'brewerID_lookup', 'beerStyle_lookup',
#        'review_appearance_lookup', 'review_aroma_lookup',
#        'review_palate_lookup', 'review_taste_lookup', 'review_overall_lookup',
#        'vader_neg', 'vader_neu', 'vader_pos', 'time_from_beginning',
#        'weekend_review', 'time_from_beginning_lookup',
#        'weekday_central_lookup', 'month_lookup', 'distance_from_july_lookup',
#        'vader_neg_lookup', 'vader_neu_lookup', 'vader_pos_lookup'],
#       dtype='object')

# %%
df[['review_appearance', 'review_aroma', 'review_palate', 'review_taste', 'review_overall']]
# Out:
#          review_appearance  review_aroma  review_palate  review_taste  \
# 2291588                  5             8              4            10
# 1651460                  5             6              5             9
# 2146614                  3            10              4             9
# 2182000                  4             7              5             9
# 2171356                  3             7              2             6
# 2696165                  4            10              4             9
# 1710138                  4             6              2             2
# 144972                   2             1              2             2
# 2694336                  4             9              5             8
# 446495                   2             3              1             3
# 1276101                  3             6              3             6
# 863982                   4             7              3             7
# 2815699                  3             4              3             7
# 1176409                  5            10              4             9
# 1918664                  4             6              3             8
# 2517046                  5             8              3             6
# 1716690                  2             4              2             4
# 6173                     4             9              3             9
# 1527492                  3             4              2             4
# 1405806                  2             6              2             4
# 862311                   4            10              3             6
# 1749713                  4             9              3             9
# 11496                    3             7              4             7
# 2696164                  5             8              5             8
# 912978                   3             6              3             5
# 33328                    5             9              5            10
# 862378                   4            10              4             7
# 778301                   3             5              3             5
# 1921274                  3             7              4             7
# 809629                   1             2              1             2
# ...                    ...           ...            ...           ...
# 661134                   4             8              4             9
# 54572                    3             6              3             6
# 662973                   3             7              4             7
# 2034972                  3             8              3             7
# 2442590                  3             6              2             6
# 1737108                  3             7              4             7
# 27950                    4             8              4             8
# 1352297                  3             7              3             8
# 218302                   3             7              3             7
# 2923932                  3             7              4             8
# 2081619                  4             8              5             9
# 2735800                  3             5              2             5
# 1113417                  4             8              4             8
# 2644366                  4             8              4             9
# 2439584                  4             7              3             7
# 27980                    4             7              4             8
# 682010                   3             6              3             6
# 1317981                  4             7              4             9
# 1366938                  2             5              2             6
# 1707863                  3             7              3             7
# 2673396                  3             4              2             4
# 296086                   3             7              5             8
# 533711                   5             7              4             8
# 2095300                  4             7              4             8
# 2399492                  3             6              3             7
# 68075                    4             8              4             8
# 2531407                  3             6              3             6
# 2005353                  3             7              3             7
# 16853                    3             5              3             6
# 357340                   3             7              3             7
#
#          review_overall
# 2291588              20
# 1651460              17
# 2146614              18
# 2182000              17
# 2171356              10
# 2696165              18
# 1710138               3
# 144972                2
# 2694336              17
# 446495                5
# 1276101              13
# 863982               15
# 2815699              14
# 1176409              18
# 1918664              14
# 2517046              15
# 1716690               8
# 6173                 18
# 1527492               7
# 1405806               8
# 862311               14
# 1749713              16
# 11496                17
# 2696164              17
# 912978               13
# 33328                19
# 862378               18
# 778301               10
# 1921274              16
# 809629                1
# ...                 ...
# 661134               17
# 54572                12
# 662973               15
# 2034972              15
# 2442590              12
# 1737108              15
# 27950                17
# 1352297              15
# 218302               15
# 2923932              15
# 2081619              15
# 2735800              10
# 1113417              17
# 2644366              18
# 2439584              13
# 27980                17
# 682010               12
# 1317981              16
# 1366938               9
# 1707863              15
# 2673396               8
# 296086               16
# 533711               14
# 2095300              14
# 2399492              14
# 68075                18
# 2531407              11
# 2005353              14
# 16853                11
# 357340               14
#
# [2631746 rows x 5 columns]

# %% [markdown]
# We must split the training set in two. Half will be used to do collaborative filtering. The other half will be used to train a classifier. This 50-50 ratio picked slightly naively. May change this in the future.

# %%
#SVD_set, train_set = train_test_split(df, test_size=0.5)

# %%
#SVD_set.to_pickle(path='SVD_set.pkl')
#train_set.to_pickle(path='train_set.pkl')

SVD_set = pd.read_pickle('SVD_set.pkl')
train_set = pd.read_pickle('train_set.pkl')
#NB: RERUN ALL THE COLLABORATIVE FILTERING MODELS!!!

# %%
SVD_set.count()
# Out:
# beerID                        1315873
# beer_name                     1315873
# abv                           1315873
# abv_listed                    1315873
# brewerID                      1315873
# beer_style                    1315873
# reviewer_username             1315873
# review_appearance             1315873
# review_aroma                  1315873
# review_palate                 1315873
# review_taste                  1315873
# review_overall                1315873
# review_text                   1315873
# review_unix_time              1315873
# weekday_central               1315873
# day_of_year                   1315873
# month                         1315873
# distance_from_july            1315873
# text_filtered                 1315873
# text_simple                   1315873
# sentiment_vader               1315873
# text_lookup                   1315873
# abv_lookup                    1315873
# brewerID_lookup               1315873
# beerStyle_lookup              1315873
# review_appearance_lookup      1315873
# review_aroma_lookup           1315873
# review_palate_lookup          1315873
# review_taste_lookup           1315873
# review_overall_lookup         1315873
# vader_neg                     1315873
# vader_neu                     1315873
# vader_pos                     1315873
# time_from_beginning           1315873
# weekend_review                1315873
# time_from_beginning_lookup    1315873
# weekday_central_lookup        1315873
# month_lookup                  1315873
# distance_from_july_lookup     1315873
# vader_neg_lookup              1315873
# vader_neu_lookup              1315873
# vader_pos_lookup              1315873
# dtype: int64

# %%
train_set.count()
# Out:
# beerID                        1315873
# beer_name                     1315873
# abv                           1315873
# abv_listed                    1315873
# brewerID                      1315873
# beer_style                    1315873
# reviewer_username             1315873
# review_appearance             1315873
# review_aroma                  1315873
# review_palate                 1315873
# review_taste                  1315873
# review_overall                1315873
# review_text                   1315873
# review_unix_time              1315873
# weekday_central               1315873
# day_of_year                   1315873
# month                         1315873
# distance_from_july            1315873
# text_filtered                 1315873
# text_simple                   1315873
# sentiment_vader               1315873
# text_lookup                   1315873
# abv_lookup                    1315873
# brewerID_lookup               1315873
# beerStyle_lookup              1315873
# review_appearance_lookup      1315873
# review_aroma_lookup           1315873
# review_palate_lookup          1315873
# review_taste_lookup           1315873
# review_overall_lookup         1315873
# vader_neg                     1315873
# vader_neu                     1315873
# vader_pos                     1315873
# time_from_beginning           1315873
# weekend_review                1315873
# time_from_beginning_lookup    1315873
# weekday_central_lookup        1315873
# month_lookup                  1315873
# distance_from_july_lookup     1315873
# vader_neg_lookup              1315873
# vader_neu_lookup              1315873
# vader_pos_lookup              1315873
# dtype: int64

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(SVD_set[['reviewer_username', 'beerID', 'review_appearance']], reader)
data.split(n_folds=5)

appearanaceSVD = SVD()
evaluate(appearanaceSVD, data, measures=['RMSE', 'MAE'])

file_name = os.path.expanduser('~/appearanaceSVD_dump')
dump.dump(file_name, algo=appearanaceSVD)
# Out:
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-793306184f2c> in <module>()
#       4
#       5 appearanaceSVD = SVD()
# ----> 6 evaluate(appearanaceSVD, data, measures=['RMSE', 'MAE'])
#       7
#       8 file_name = os.path.expanduser('~/appearanaceSVD_dump')
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/surprise/evaluate.py in evaluate(algo, data, measures, with_dump, dump_dir, verbose)
#      63
#      64         # train and test algorithm. Keep all rating predictions in a list
# ---> 65         algo.train(trainset)
#      66         predictions = algo.test(testset, verbose=(verbose == 2))
#      67
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/surprise/prediction_algorithms/matrix_factorization.pyx in surprise.prediction_algorithms.matrix_factorization.SVD.train()
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/surprise/prediction_algorithms/matrix_factorization.pyx in surprise.prediction_algorithms.matrix_factorization.SVD.sgd()
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/surprise/dataset.py in all_ratings(self)
#     655         for u, u_ratings in iteritems(self.ur):
#     656             for i, r in u_ratings:
# --> 657                 yield u, i, r
#     658
#     659     def build_testset(self):
#
# KeyboardInterrupt:

# %%
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(SVD_set[['reviewer_username', 'beerID', 'review_aroma']], reader)
data.split(n_folds=5)

aromaSVD = SVD()
evaluate(aromaSVD, data, measures=['RMSE', 'MAE'])

file_name = os.path.expanduser('~/aromaSVD_dump')
dump.dump(file_name, algo=aromaSVD)
# Out:
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 1.1902
# MAE:  0.8873
# ------------
# Fold 2
# RMSE: 1.1907
# MAE:  0.8882
# ------------
# Fold 3
# RMSE: 1.1888
# MAE:  0.8855
# ------------
# Fold 4
# RMSE: 1.1868
# MAE:  0.8849
# ------------
# Fold 5
# RMSE: 1.1899
# MAE:  0.8883
# ------------
# ------------
# Mean RMSE: 1.1893
# Mean MAE : 0.8868
# ------------
# ------------

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(SVD_set[['reviewer_username', 'beerID', 'review_palate']], reader)
data.split(n_folds=5)

palateSVD = SVD()
evaluate(palateSVD, data, measures=['RMSE', 'MAE'])

file_name = os.path.expanduser('~/palateSVD_dump')
dump.dump(file_name, algo=palateSVD)
# Out:
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.6731
# MAE:  0.5179
# ------------
# Fold 2
# RMSE: 0.6732
# MAE:  0.5178
# ------------
# Fold 3
# RMSE: 0.6737
# MAE:  0.5175
# ------------
# Fold 4
# RMSE: 0.6738
# MAE:  0.5185
# ------------
# Fold 5
# RMSE: 0.6744
# MAE:  0.5189
# ------------
# ------------
# Mean RMSE: 0.6736
# Mean MAE : 0.5181
# ------------
# ------------

# %%
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(SVD_set[['reviewer_username', 'beerID', 'review_taste']], reader)
data.split(n_folds=5)

tasteSVD = SVD()
evaluate(tasteSVD, data, measures=['RMSE', 'MAE'])

file_name = os.path.expanduser('~/tasteSVD_dump')
dump.dump(file_name, algo=tasteSVD)
# Out:
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 1.2252
# MAE:  0.9163
# ------------
# Fold 2
# RMSE: 1.2243
# MAE:  0.9148
# ------------
# Fold 3
# RMSE: 1.2239
# MAE:  0.9150
# ------------
# Fold 4
# RMSE: 1.2256
# MAE:  0.9160
# ------------
# Fold 5
# RMSE: 1.2290
# MAE:  0.9194
# ------------
# ------------
# Mean RMSE: 1.2256
# Mean MAE : 0.9163
# ------------
# ------------

# %%
reader = Reader(rating_scale=(1, 20))
data = Dataset.load_from_df(SVD_set[['reviewer_username', 'beerID', 'review_overall']], reader)
data.split(n_folds=5)

overallSVD = SVD()
evaluate(overallSVD, data, measures=['RMSE', 'MAE'])

file_name = os.path.expanduser('~/overallSVD_dump')
dump.dump(file_name, algo=overallSVD)
# Out:
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 2.4827
# MAE:  1.8149
# ------------
# Fold 2
# RMSE: 2.4896
# MAE:  1.8182
# ------------
# Fold 3
# RMSE: 2.4831
# MAE:  1.8161
# ------------
# Fold 4
# RMSE: 2.4791
# MAE:  1.8122
# ------------
# Fold 5
# RMSE: 2.4970
# MAE:  1.8230
# ------------
# ------------
# Mean RMSE: 2.4863
# Mean MAE : 1.8169
# ------------
# ------------

# %%
aggregation={
    'beerID' : {
        'beerID_count' : 'count'
    },
    'abv' : {
        'avgABV' : 'mean',
        'medianABV' : 'median',
        'maxABV' : 'max',
        'minABV' : 'min',
        'ABVrange' : lambda x: max(x) - min(x)
    },
    'abv_listed' : {
        'num_abv_listed' : lambda x: int(sum(x)) 
    },
    'brewerID' : {
        'num_brewers' : lambda x: x.nunique()
    },
    'beer_style' : {
        'numBeerStyles' : lambda x : x.nunique()
    },
    'review_appearance' : {
        'avgAppearanceScore' : 'mean',
        'medianAppearanceScore' : 'median',
        'maxAppearanceScore' : 'max',
        'minAppearanceScore' : 'min',
        'appearanceScoreRange' : lambda x: max(x) - min(x)
    },
    'review_aroma' : {
        'avgAromaScore' : 'mean',
        'medianAromaScore' : 'median',
        'maxAromaScore' : 'max',
        'minAromaScore' : 'min',
        'aromaScoreRange' : lambda x: max(x) - min(x)
    },
    'review_palate' : {
        'avgPalateScore' : 'mean',
        'medianPalateScore' : 'median',
        'maxPalateScore' : 'max',
        'minPalateScore' : 'min',
        'palateScoreRange' : lambda x: max(x) - min(x)
    },
    'review_taste' : {
        'avgTasteScore' : 'mean',
        'medianTasteScore' : 'median',
        'maxTasteScore' : 'max',
        'minTasteScore' : 'min',
        'tasteScoreRange' : lambda x: max(x) - min(x)
    },
    'review_overall' : {
        'avgOverallScore' : 'mean',
        'medianOverallScore' : 'median',
        'maxOverallScore' : 'max',
        'minOverallScore' : 'min',
        'overallScoreRange' : lambda x: max(x) - min(x)
    },
    'text_lookup' : {
        'text_list' : lambda x : [[item[0],item[2]] for item in x]
    },
    'time_from_beginning' : {
        'avgTimestamp' : 'mean',
        'medianTimestamp' : 'median',
        'maxTimestamp' : 'max',
        'minTimestamp' : 'min',
        'TimestampRange' : lambda x: max(x) - min(x)
    },
    'weekday_central' : {
        'most_common_weekday' : lambda x: x.value_counts().index[0],
        'number_of_weekdays' : lambda x: x.nunique()
    },
    'weekend_review' : {
        'num_weekend_reviews' : 'sum'
    },
    'month' : {
        'most_common_month' : lambda x: x.value_counts().index[0],
        'number_of_months' : lambda x: x.nunique()
    },
    'distance_from_july' : {
        'avgMonthsFromJuly' : 'mean',
        'medianMonthsFromJuly' : 'median',
        'maxMonthsFromJuly' : 'max',
        'minMonthsFromJuly' : 'min',
        'monthsFromJulyRange' : lambda x: max(x) - min(x)
    },
    'vader_neg' : {
        'avgVaderNeg' : 'mean',
        'medianVaderNeg' : 'median',
        'maxVaderNeg' : 'max',
        'minVaderNeg' : 'min',
        'vaderNegRange' : lambda x: max(x) - min(x)
    },
    'vader_neu' : {
        'avgVaderNeu' : 'mean',
        'medianVaderNeu' : 'median',
        'maxVaderNeu' : 'max',
        'minVaderNeu' : 'min',
        'vaderNeuRange' : lambda x: max(x) - min(x)
    },
    'vader_pos' : {
        'avgVaderPos' : 'mean',
        'medianVaderPos' : 'median',
        'maxVaderPos' : 'max',
        'minVaderPos' : 'min',
        'vaderPosRange' : lambda x: max(x) - min(x)
    }
}
aggByUser_df = SVD_set.groupby('reviewer_username').agg(aggregation)
# Out:
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/pandas/core/groupby.py:4036: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
aggregation={
    'reviewer_username' : {
        'user_count' : 'count'
    },
    'abv' : {
        'avgABV' : 'mean',
        'medianABV' : 'median',
        'maxABV' : 'max',
        'minABV' : 'min',
        'ABVrange' : lambda x: max(x) - min(x)
    },
    'abv_listed' : {
        'num_abv_listed' : lambda x: int(sum(x)) 
    },
    'beer_style' : {
        'numBeerStyles' : lambda x: x.value_counts().index[0]
    },
    'review_appearance' : {
        'avgAppearanceScore' : 'mean',
        'medianAppearanceScore' : 'median',
        'maxAppearanceScore' : 'max',
        'minAppearanceScore' : 'min',
        'appearanceScoreRange' : lambda x: max(x) - min(x)
    },
    'review_aroma' : {
        'avgAromaScore' : 'mean',
        'medianAromaScore' : 'median',
        'maxAromaScore' : 'max',
        'minAromaScore' : 'min',
        'aromaScoreRange' : lambda x: max(x) - min(x)
    },
    'review_palate' : {
        'avgPalateScore' : 'mean',
        'medianPalateScore' : 'median',
        'maxPalateScore' : 'max',
        'minPalateScore' : 'min',
        'palateScoreRange' : lambda x: max(x) - min(x)
    },
    'review_taste' : {
        'avgTasteScore' : 'mean',
        'medianTasteScore' : 'median',
        'maxTasteScore' : 'max',
        'minTasteScore' : 'min',
        'tasteScoreRange' : lambda x: max(x) - min(x)
    },
    'review_overall' : {
        'avgOverallScore' : 'mean',
        'medianOverallScore' : 'median',
        'maxOverallScore' : 'max',
        'minOverallScore' : 'min',
        'overallScoreRange' : lambda x: max(x) - min(x)
    },
    'text_lookup' : {
        'text_list' : lambda x : [[item[1],item[2]] for item in x]
    },
    'time_from_beginning' : {
        'avgTimestamp' : 'mean',
        'medianTimestamp' : 'median',
        'maxTimestamp' : 'max',
        'minTimestamp' : 'min',
        'TimestampRange' : lambda x: max(x) - min(x)
    },
    'weekday_central' : {
        'most_common_weekday' : lambda x: x.value_counts().index[0],
        'number_of_weekdays' : lambda x: x.nunique()
    },
    'weekend_review' : {
        'num_weekend_reviews' : 'sum'
    },
    'month' : {
        'most_common_month' : lambda x: x.value_counts().index[0],
        'number_of_months' : lambda x: x.nunique()
    },
    'distance_from_july' : {
        'avgMonthsFromJuly' : 'mean',
        'medianMonthsFromJuly' : 'median',
        'maxMonthsFromJuly' : 'max',
        'minMonthsFromJuly' : 'min',
        'monthsFromJulyRange' : lambda x: max(x) - min(x)
    },
    'vader_neg' : {
        'avgVaderNeg' : 'mean',
        'medianVaderNeg' : 'median',
        'maxVaderNeg' : 'max',
        'minVaderNeg' : 'min',
        'vaderNegRange' : lambda x: max(x) - min(x)
    },
    'vader_neu' : {
        'avgVaderNeu' : 'mean',
        'medianVaderNeu' : 'median',
        'maxVaderNeu' : 'max',
        'minVaderNeu' : 'min',
        'vaderNeuRange' : lambda x: max(x) - min(x)
    },
    'vader_pos' : {
        'avgVaderPos' : 'mean',
        'medianVaderPos' : 'median',
        'maxVaderPos' : 'max',
        'minVaderPos' : 'min',
        'vaderPosRange' : lambda x: max(x) - min(x)
    }
}
aggByProduct_df = SVD_set.groupby('beerID').agg(aggregation)
# Out:
# /Users/conhealy/anaconda2/envs/py35/lib/python3.5/site-packages/pandas/core/groupby.py:4036: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
aggByUser_df.head()
# Out:
#                   time_from_beginning                            \
#                        TimestampRange minTimestamp maxTimestamp
# reviewer_username
#  -BB-99                             0     49593600     49593600
#  007lund                     22723200     71971200     94694400
#  0087341                            0    345340800    345340800
#  00cobraR                   176860800    130032000    306892800
#  0110x011                     3715200    269395200    273110400
#
#                                                     review_appearance  \
#                   medianTimestamp  avgTimestamp medianAppearanceScore
# reviewer_username
#  -BB-99                  49593600  4.959360e+07                   5.0
#  007lund                 74995200  7.814053e+07                   3.0
#  0087341                345340800  3.453408e+08                   5.0
#  00cobraR               208396800  2.052347e+08                   3.0
#  0110x011               269395200  2.702208e+08                   4.0
#
#                                                                               \
#                   maxAppearanceScore appearanceScoreRange avgAppearanceScore
# reviewer_username
#  -BB-99                            5                    0           5.000000
#  007lund                           5                    4           3.340426
#  0087341                           5                    0           5.000000
#  00cobraR                          5                    4           3.218284
#  0110x011                          5                    2           4.000000
#
#                                            ...         vader_neg  \
#                   minAppearanceScore       ...       avgVaderNeg
# reviewer_username                          ...
#  -BB-99                            5       ...          0.000000
#  007lund                           1       ...          0.067766
#  0087341                           5       ...          0.000000
#  00cobraR                          1       ...          0.051487
#  0110x011                          3       ...          0.033333
#
#                              month                        weekend_review  \
#                   number_of_months most_common_month num_weekend_reviews
# reviewer_username
#  -BB-99                          1                11                 0.0
#  007lund                        10                07                16.0
#  0087341                         1                03                 0.0
#  00cobraR                       12                05               273.0
#  0110x011                        2                10                 9.0
#
#                      brewerID    review_overall                  \
#                   num_brewers overallScoreRange avgOverallScore
# reviewer_username
#  -BB-99                     1                 0        8.000000
#  007lund                   32                17       11.893617
#  0087341                    1                 0       19.000000
#  00cobraR                 201                17       12.240672
#  0110x011                   9                 6       15.555556
#
#
#                   maxOverallScore medianOverallScore minOverallScore
# reviewer_username
#  -BB-99                         8                8.0               8
#  007lund                       18               13.0               1
#  0087341                       19               19.0              19
#  00cobraR                      18               13.0               1
#  0110x011                      18               15.0              12
#
# [5 rows x 65 columns]

# %%
aggByUser_df.columns = aggByUser_df.columns.get_level_values(0)

# %%
aggByUser_df.head()
# Out:
#                    time_from_beginning  time_from_beginning  \
# reviewer_username
#  -BB-99                              0             49593600
#  007lund                      22723200             71971200
#  0087341                             0            345340800
#  00cobraR                    176860800            130032000
#  0110x011                      3715200            269395200
#
#                    time_from_beginning  time_from_beginning  \
# reviewer_username
#  -BB-99                       49593600             49593600
#  007lund                      94694400             74995200
#  0087341                     345340800            345340800
#  00cobraR                    306892800            208396800
#  0110x011                    273110400            269395200
#
#                    time_from_beginning  review_appearance  review_appearance  \
# reviewer_username
#  -BB-99                   4.959360e+07                5.0                  5
#  007lund                  7.814053e+07                3.0                  5
#  0087341                  3.453408e+08                5.0                  5
#  00cobraR                 2.052347e+08                3.0                  5
#  0110x011                 2.702208e+08                4.0                  5
#
#                    review_appearance  review_appearance  review_appearance  \
# reviewer_username
#  -BB-99                            0           5.000000                  5
#  007lund                           4           3.340426                  1
#  0087341                           0           5.000000                  5
#  00cobraR                          4           3.218284                  1
#  0110x011                          2           4.000000                  3
#
#                         ...        vader_neg  month  month  weekend_review  \
# reviewer_username       ...
#  -BB-99                 ...         0.000000      1     11             0.0
#  007lund                ...         0.067766     10     07            16.0
#  0087341                ...         0.000000      1     03             0.0
#  00cobraR               ...         0.051487     12     05           273.0
#  0110x011               ...         0.033333      2     10             9.0
#
#                    brewerID  review_overall  review_overall  review_overall  \
# reviewer_username
#  -BB-99                   1               0        8.000000               8
#  007lund                 32              17       11.893617              18
#  0087341                  1               0       19.000000              19
#  00cobraR               201              17       12.240672              18
#  0110x011                 9               6       15.555556              18
#
#                    review_overall  review_overall
# reviewer_username
#  -BB-99                       8.0               8
#  007lund                     13.0               1
#  0087341                     19.0              19
#  00cobraR                    13.0               1
#  0110x011                    15.0              12
#
# [5 rows x 65 columns]

# %%
aggByProduct_df.columns = aggByProduct_df.columns.get_level_values(0)

# %%
aggByProduct_df.head()
# Out:
#         time_from_beginning  time_from_beginning  time_from_beginning  \
# beerID
# 1                 339638400              2073600            341712000
# 2                 340070400              9072000            349142400
# 3                 332294400             17625600            349920000
# 4                 316915200             33955200            350870400
# 5                 329184000             19353600            348537600
#
#         time_from_beginning  time_from_beginning  review_appearance  \
# beerID
# 1                 156168000         1.673195e+08                4.0
# 2                 222220800         2.111082e+08                3.0
# 3                 286718400         2.718129e+08                3.0
# 4                 224812800         2.198255e+08                3.0
# 5                 247449600         2.450835e+08                3.0
#
#         review_appearance  review_appearance  review_appearance  \
# beerID
# 1                       5                  4           4.151709
# 2                       5                  4           3.086154
# 3                       5                  4           3.151163
# 4                       5                  4           3.130081
# 5                       5                  4           3.224138
#
#         review_appearance       ...        vader_neu  vader_neu  vader_neu  \
# beerID                          ...
# 1                       1       ...            0.000     0.7690      1.000
# 2                       1       ...            0.000     0.8110      1.000
# 3                       1       ...            0.491     0.7930      0.509
# 4                       1       ...            0.461     0.7970      0.539
# 5                       1       ...            0.000     0.8065      1.000
#
#         vader_neu    beer_style  review_overall  review_overall  \
# beerID
# 1        0.752746     Dry Stout              19       13.668803
# 2        0.793006        Vienna              17       10.673846
# 3        0.784314   Heller Bock              17       11.691860
# 4        0.786114   Heller Bock              14       11.609756
# 5        0.796741     Amber Ale              13       11.114943
#
#         review_overall  review_overall  review_overall
# beerID
# 1                   20            14.0               1
# 2                   20            11.0               3
# 3                   19            12.0               2
# 4                   17            12.0               3
# 5                   18            11.0               5
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Join dataframes together to build final training set

# %%
train_set['beerID'].count()
# Out:
# 1315873

# %%
aggByUser_df['reviewer_username']=aggByUser_df.index

# %%
aggByProduct_df['beerID']=aggByProduct_df.index

# %%
aggByUser_df.head()
# Out:
#                    time_from_beginning  time_from_beginning  \
# reviewer_username
#  -BB-99                              0             49593600
#  007lund                      22723200             71971200
#  0087341                             0            345340800
#  00cobraR                    176860800            130032000
#  0110x011                      3715200            269395200
#
#                    time_from_beginning  time_from_beginning  \
# reviewer_username
#  -BB-99                       49593600             49593600
#  007lund                      94694400             74995200
#  0087341                     345340800            345340800
#  00cobraR                    306892800            208396800
#  0110x011                    273110400            269395200
#
#                    time_from_beginning  review_appearance  review_appearance  \
# reviewer_username
#  -BB-99                   4.959360e+07                5.0                  5
#  007lund                  7.814053e+07                3.0                  5
#  0087341                  3.453408e+08                5.0                  5
#  00cobraR                 2.052347e+08                3.0                  5
#  0110x011                 2.702208e+08                4.0                  5
#
#                    review_appearance  review_appearance  review_appearance  \
# reviewer_username
#  -BB-99                            0           5.000000                  5
#  007lund                           4           3.340426                  1
#  0087341                           0           5.000000                  5
#  00cobraR                          4           3.218284                  1
#  0110x011                          2           4.000000                  3
#
#                          ...          month  month  weekend_review  brewerID  \
# reviewer_username        ...
#  -BB-99                  ...              1     11             0.0         1
#  007lund                 ...             10     07            16.0        32
#  0087341                 ...              1     03             0.0         1
#  00cobraR                ...             12     05           273.0       201
#  0110x011                ...              2     10             9.0         9
#
#                    review_overall  review_overall  review_overall  \
# reviewer_username
#  -BB-99                         0        8.000000               8
#  007lund                       17       11.893617              18
#  0087341                        0       19.000000              19
#  00cobraR                      17       12.240672              18
#  0110x011                       6       15.555556              18
#
#                    review_overall  review_overall  reviewer_username
# reviewer_username
#  -BB-99                       8.0               8             -BB-99
#  007lund                     13.0               1            007lund
#  0087341                     19.0              19            0087341
#  00cobraR                    13.0               1           00cobraR
#  0110x011                    15.0              12           0110x011
#
# [5 rows x 66 columns]

# %%
df_partMerge = pd.merge(train_set, aggByUser_df, on='reviewer_username', how='outer', 
                        suffixes=('_orig', '_userAgg'))

# %%
df_partMerge['brewerID_orig'].count()
# Out:
# 1315873

# %%
df_partMerge.columns.values
# Out:
# array(['beerID_orig', 'beer_name', 'abv_orig', 'abv_listed_orig',
#        'brewerID_orig', 'beer_style_orig', 'reviewer_username',
#        'review_appearance_orig', 'review_aroma_orig', 'review_palate_orig',
#        'review_taste_orig', 'review_overall_orig', 'review_text',
#        'review_unix_time', 'weekday_central_orig', 'day_of_year',
#        'month_orig', 'distance_from_july_orig', 'text_filtered',
#        'text_simple', 'sentiment_vader', 'text_lookup_orig', 'abv_lookup',
#        'brewerID_lookup', 'beerStyle_lookup', 'review_appearance_lookup',
#        'review_aroma_lookup', 'review_palate_lookup',
#        'review_taste_lookup', 'review_overall_lookup', 'vader_neg_orig',
#        'vader_neu_orig', 'vader_pos_orig', 'time_from_beginning_orig',
#        'weekend_review_orig', 'time_from_beginning_lookup',
#        'weekday_central_lookup', 'month_lookup',
#        'distance_from_july_lookup', 'vader_neg_lookup', 'vader_neu_lookup',
#        'vader_pos_lookup', 'time_from_beginning_userAgg',
#        'time_from_beginning_userAgg', 'time_from_beginning_userAgg',
#        'time_from_beginning_userAgg', 'time_from_beginning_userAgg',
#        'review_appearance_userAgg', 'review_appearance_userAgg',
#        'review_appearance_userAgg', 'review_appearance_userAgg',
#        'review_appearance_userAgg', 'review_palate_userAgg',
#        'review_palate_userAgg', 'review_palate_userAgg',
#        'review_palate_userAgg', 'review_palate_userAgg', 'abv_userAgg',
#        'abv_userAgg', 'abv_userAgg', 'abv_userAgg', 'abv_userAgg',
#        'review_taste_userAgg', 'review_taste_userAgg',
#        'review_taste_userAgg', 'review_taste_userAgg',
#        'review_taste_userAgg', 'weekday_central_userAgg',
#        'weekday_central_userAgg', 'distance_from_july_userAgg',
#        'distance_from_july_userAgg', 'distance_from_july_userAgg',
#        'distance_from_july_userAgg', 'distance_from_july_userAgg',
#        'vader_neu_userAgg', 'vader_neu_userAgg', 'vader_neu_userAgg',
#        'vader_neu_userAgg', 'vader_neu_userAgg', 'abv_listed_userAgg',
#        'beerID_userAgg', 'text_lookup_userAgg', 'beer_style_userAgg',
#        'vader_pos_userAgg', 'vader_pos_userAgg', 'vader_pos_userAgg',
#        'vader_pos_userAgg', 'vader_pos_userAgg', 'review_aroma_userAgg',
#        'review_aroma_userAgg', 'review_aroma_userAgg',
#        'review_aroma_userAgg', 'review_aroma_userAgg', 'vader_neg_userAgg',
#        'vader_neg_userAgg', 'vader_neg_userAgg', 'vader_neg_userAgg',
#        'vader_neg_userAgg', 'month_userAgg', 'month_userAgg',
#        'weekend_review_userAgg', 'brewerID_userAgg',
#        'review_overall_userAgg', 'review_overall_userAgg',
#        'review_overall_userAgg', 'review_overall_userAgg',
#        'review_overall_userAgg'], dtype=object)

# %%
df_merged = pd.merge(df_partMerge, aggByProduct_df, left_on='beerID_orig', right_on='beerID', how='outer'
         , suffixes=('', '_prodAgg'))

# %%
# number of rows increases because some beers aren't reviewed at all
df_merged['beerID'].count()
# Out:
# 1307955

# %%
#dfm1, dfm2 = np.array_split(df_merged, 2)
#dfm1.to_pickle(path='./df_merged1.pkl')
#dfm2.to_pickle(path='./df_merged2.pkl')

dfm1 = pd.read_pickle('df_merged1.pkl')
dfm2 = pd.read_pickle('df_merged2.pkl')
df_merged=pd.concat([dfm1,dfm2])

# %%
df_merged.columns.values
# Out:
# array(['beerID', 'beer_name', 'abv', 'abv_listed', 'brewerID',
#        'beer_style', 'reviewer_username', 'review_appearance',
#        'review_aroma', 'review_palate', 'review_taste', 'review_overall',
#        'review_text', 'review_unix_time', 'weekday_central', 'day_of_year',
#        'month', 'distance_from_july', 'text_filtered', 'text_simple',
#        'sentiment_vader', 'text_lookup', 'abv_lookup', 'brewerID_lookup',
#        'beerStyle_lookup', 'review_appearance_lookup',
#        'review_aroma_lookup', 'review_palate_lookup',
#        'review_taste_lookup', 'review_overall_lookup', 'vader_neg',
#        'vader_neu', 'vader_pos', 'time_from_beginning', 'weekend_review',
#        'time_from_beginning_lookup', 'weekday_central_lookup',
#        'month_lookup', 'distance_from_july_lookup', 'vader_neg_lookup',
#        'vader_neu_lookup', 'vader_pos_lookup', 'num_weekend_reviews',
#        'brewerID_list', 'beerID_count', 'vader_neg_list',
#        'distance_from_july_list', 'reviewAroma_list', 'text_list',
#        'month_list', 'weekday_central_list', 'vader_pos_list', 'abv_list',
#        'reviewOverall_list', 'reviewAppearance_list', 'reviewTaste_list',
#        'vader_neu_list', 'reviewPalate_list', 'num_abv_listed',
#        'time_from_beginning_list', 'beerStyle_list', '',
#        'num_weekend_reviews_prodAgg', 'vader_neg_list_prodAgg',
#        'distance_from_july_list_prodAgg', 'num_brewers', 'user_count',
#        'text_list_prodAgg', 'reviewAroma_list_prodAgg',
#        'weekday_central_list_prodAgg', 'ABV', 'vader_pos_list_prodAgg',
#        'month_list_prodAgg', 'reviewOverall_list_prodAgg',
#        'reviewAppearance_list_prodAgg', 'reviewTaste_list_prodAgg',
#        'vader_neu_list_prodAgg', 'reviewPalate_list_prodAgg',
#        'num_abv_listed_prodAgg', 'time_from_beginning_list_prodAgg',
#        'numBeerStyles'], dtype=object)

# %%
df_merged.head()
# Out:
#    beerID               beer_name  abv  abv_listed  brewerID beer_style  \
# 0    5868   St Peters Organic Ale  4.5        True       974     Bitter
# 1    5868   St Peters Organic Ale  4.5        True       974     Bitter
# 2    5868   St Peters Organic Ale  4.5        True       974     Bitter
# 3    5868   St Peters Organic Ale  4.5        True       974     Bitter
# 4    5868   St Peters Organic Ale  4.5        True       974     Bitter
#
#   reviewer_username  review_appearance  review_aroma  review_palate  \
# 0        abemorsten                  3             6              4
# 1            jazz88                  3             6              3
# 2          zach8270                  3             6              3
# 3       Angeloregon                  4             7              3
# 4        bierkoning                  3             6              2
#
#        ...                                  vader_pos_list_prodAgg  \
# 0      ...       [[ abemorsten, 0.179], [ hayduke, 0.068], [ co...
# 1      ...       [[ abemorsten, 0.179], [ hayduke, 0.068], [ co...
# 2      ...       [[ abemorsten, 0.179], [ hayduke, 0.068], [ co...
# 3      ...       [[ abemorsten, 0.179], [ hayduke, 0.068], [ co...
# 4      ...       [[ abemorsten, 0.179], [ hayduke, 0.068], [ co...
#
#                                   month_list_prodAgg  \
# 0  [[ abemorsten, 10], [ hayduke, 01], [ colts901...
# 1  [[ abemorsten, 10], [ hayduke, 01], [ colts901...
# 2  [[ abemorsten, 10], [ hayduke, 01], [ colts901...
# 3  [[ abemorsten, 10], [ hayduke, 01], [ colts901...
# 4  [[ abemorsten, 10], [ hayduke, 01], [ colts901...
#
#                           reviewOverall_list_prodAgg  \
# 0  [[ abemorsten, 14], [ hayduke, 14], [ colts901...
# 1  [[ abemorsten, 14], [ hayduke, 14], [ colts901...
# 2  [[ abemorsten, 14], [ hayduke, 14], [ colts901...
# 3  [[ abemorsten, 14], [ hayduke, 14], [ colts901...
# 4  [[ abemorsten, 14], [ hayduke, 14], [ colts901...
#
#                        reviewAppearance_list_prodAgg  \
# 0  [[ abemorsten, 3], [ hayduke, 3], [ colts9016,...
# 1  [[ abemorsten, 3], [ hayduke, 3], [ colts9016,...
# 2  [[ abemorsten, 3], [ hayduke, 3], [ colts9016,...
# 3  [[ abemorsten, 3], [ hayduke, 3], [ colts9016,...
# 4  [[ abemorsten, 3], [ hayduke, 3], [ colts9016,...
#
#                             reviewTaste_list_prodAgg  \
# 0  [[ abemorsten, 6], [ hayduke, 6], [ colts9016,...
# 1  [[ abemorsten, 6], [ hayduke, 6], [ colts9016,...
# 2  [[ abemorsten, 6], [ hayduke, 6], [ colts9016,...
# 3  [[ abemorsten, 6], [ hayduke, 6], [ colts9016,...
# 4  [[ abemorsten, 6], [ hayduke, 6], [ colts9016,...
#
#                               vader_neu_list_prodAgg  \
# 0  [[ abemorsten, 0.757], [ hayduke, 0.913], [ co...
# 1  [[ abemorsten, 0.757], [ hayduke, 0.913], [ co...
# 2  [[ abemorsten, 0.757], [ hayduke, 0.913], [ co...
# 3  [[ abemorsten, 0.757], [ hayduke, 0.913], [ co...
# 4  [[ abemorsten, 0.757], [ hayduke, 0.913], [ co...
#
#                            reviewPalate_list_prodAgg  num_abv_listed_prodAgg  \
# 0  [[ abemorsten, 4], [ hayduke, 3], [ colts9016,...                    True
# 1  [[ abemorsten, 4], [ hayduke, 3], [ colts9016,...                    True
# 2  [[ abemorsten, 4], [ hayduke, 3], [ colts9016,...                    True
# 3  [[ abemorsten, 4], [ hayduke, 3], [ colts9016,...                    True
# 4  [[ abemorsten, 4], [ hayduke, 3], [ colts9016,...                    True
#
#                     time_from_beginning_list_prodAgg numBeerStyles
# 0  [[ abemorsten, 300412800], [ hayduke, 21366720...        Bitter
# 1  [[ abemorsten, 300412800], [ hayduke, 21366720...        Bitter
# 2  [[ abemorsten, 300412800], [ hayduke, 21366720...        Bitter
# 3  [[ abemorsten, 300412800], [ hayduke, 21366720...        Bitter
# 4  [[ abemorsten, 300412800], [ hayduke, 21366720...        Bitter
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Remove the example in question from each lookup list
# This way the specific rreview features are not embedded in the aggregate values.

# %%
df_merged[['beerID','beerID_count']].head()
# Out:
#    beerID  beerID_count
# 0    5868           146
# 1    5868          1041
# 2    5868          1241
# 3    5868           949
# 4    5868          2424

# %%
def removekey(d, key):
    r = dict(d)
    del r[key]
    return r

# %%
df_merged.index.max()
# Out:
# 1315872

# %%
df_merged.iloc[[1315872]]
# Out:
#          beerID                            beer_name  abv  abv_listed  \
# 1315872    8647   Blackfoot River Woollybugger Wheat  5.9        True
#
#          brewerID          beer_style reviewer_username  review_appearance  \
# 1315872      1467   German Hefeweizen     buzzlightbeer                  5
#
#          review_aroma  review_palate         ...          \
# 1315872            10              5         ...
#
#             vader_pos_list_prodAgg      month_list_prodAgg  \
# 1315872  [[ buzzlightbeer, 0.147]]  [[ buzzlightbeer, 10]]
#
#         reviewOverall_list_prodAgg  reviewAppearance_list_prodAgg  \
# 1315872     [[ buzzlightbeer, 20]]          [[ buzzlightbeer, 5]]
#
#         reviewTaste_list_prodAgg     vader_neu_list_prodAgg  \
# 1315872   [[ buzzlightbeer, 10]]  [[ buzzlightbeer, 0.853]]
#
#         reviewPalate_list_prodAgg  num_abv_listed_prodAgg  \
# 1315872     [[ buzzlightbeer, 5]]                    True
#
#         time_from_beginning_list_prodAgg       numBeerStyles
# 1315872    [[ buzzlightbeer, 268358400]]   German Hefeweizen
#
# [1 rows x 81 columns]

# %%
df_merged['vader_neg_list2'] = df_merged.apply(lambda row: removekey(dict(row['vader_neg_list']), int(row['beerID'])), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-01b85969fdaf> in <module>()
# ----> 1 df_merged['vader_neg_list2'] = df_merged.apply(lambda row: removekey(dict(row['vader_neg_list']), int(row['beerID'])), axis=1)
#
# NameError: name 'df_merged' is not defined

# %%
df_merged['vader_neg_list2'] = df.apply(lambda row: [item for item in row['vader_neg_list'] if item[0]!=row['beerID'] ])

# %%
# Out:
# 2

# %%
# We woould not have review information in cases where we're trying to 
# recommend something that's not been reviewed before so we can drop all that stuff
df_merged.drop(['review_appearance', 'review_aroma', 'review_palate', 'review_taste',
               'review_overall', 'review_text', 'review_unix_time', 'weekday_central',
               'day_of_year', 'month', 'distance_from_july', 'text_filtered', 
               'text_simple', 'sentiment_vader', 'vader_neg', 'vader_neu',
               'vader_pos', 'time_from_beginning'], axis=1)

# %%
# brewer variety index - numBrewers/beerID_count
aggByUser_df['beer_variety_index'] = aggByUser_df['num_brewers']/aggByUser_df['beerID_count']

# beer style variety index - numBeerStyles/beerID_count
aggByUser_df['brewer_variety_index'] = aggByUser_df['numBeerStyles']/aggByUser_df['beerID_count']

# rate of reviewing - beerID_count/timeStampRange
aggByUser_df['rate_of_posting'] = aggByUser_df['beerID_count']/aggByUser_df['TimestampRange']

# weekday variety index - number_of_weekdays/beerID_count
aggByUser_df['weekday_variety_index'] = aggByUser_df['number_of_weekdays']/aggByUser_df['beerID_count']

# month variety index - number_of_months/beerID_count
aggByUser_df['month_variety_index'] = aggByUser_df['number_of_months']/aggByUser_df['beerID_count']

# weekend review ratio - num_weekend_reviews/beerID_count
aggByUser_df['weekend_review_ratio'] = aggByUser_df['num_weekend_reviews']/aggByUser_df['beerID_count']
