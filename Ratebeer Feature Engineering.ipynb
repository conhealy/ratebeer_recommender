# %% [markdown]
# # Ratebeer Feature Engineering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_pickle('ratebeer_clean.pkl')

# %%
df.head(20)
# Out:
#     beerID                                  beer_name  abv  abv_listed  \
# 0    63836                   John Harvards Simcoe IPA  5.4        True
# 1    63836                   John Harvards Simcoe IPA  5.4        True
# 2    71716              John Harvards Cristal Pilsner  5.0        True
# 3    64125         John Harvards Fancy Lawnmower Beer  5.4        True
# 4    64125         John Harvards Fancy Lawnmower Beer  5.4        True
# 5    31544   John Harvards Vanilla Black Velvet Stout  6.0       False
# 6    71714           John Harvards American Brown Ale  6.0       False
# 7    71719                    John Harvards Grand Cru  7.0        True
# 8    71719                    John Harvards Grand Cru  7.0        True
# 9    71719                    John Harvards Grand Cru  7.0        True
# 10   71715               John Harvards Belgian Tripel  8.5        True
# 11    1470                   John Harvards Cassis Wit  6.0       False
# 12    7721      John Harvards Dr. Jekyll and Mr. Mild  3.8        True
# 13   64126               John Harvards Yin Yang Lager  4.5        True
# 14   64126               John Harvards Yin Yang Lager  4.5        True
# 15   91592     Barley Island Barrel-Aged Count Hopula  8.0        True
# 16   91592     Barley Island Barrel-Aged Count Hopula  8.0        True
# 17   91592     Barley Island Barrel-Aged Count Hopula  8.0        True
# 18   91592     Barley Island Barrel-Aged Count Hopula  8.0        True
# 19   91592     Barley Island Barrel-Aged Count Hopula  8.0        True
#
#     brewerID                        beer_style reviewer_username  \
# 0       8481      India Pale Ale &#40;IPA&#41;            hopdog
# 1       8481      India Pale Ale &#40;IPA&#41;      TomDecapolis
# 2       8481                 Bohemian Pilsener    PhillyBeer2112
# 3       8481                            Kölsch      TomDecapolis
# 4       8481                            Kölsch            hopdog
# 5       8481                       Sweet Stout          egajdzis
# 6       8481                         Brown Ale            hopdog
# 7       8481                       Belgian Ale           JFGrind
# 8       8481                       Belgian Ale          egajdzis
# 9       8481                       Belgian Ale    PhillyBeer2112
# 10      8481                      Abbey Tripel    PhillyBeer2112
# 11      8481   Belgian White &#40;Witbier&#41;    PhillyBeer2112
# 12      8481                          Mild Ale    PhillyBeer2112
# 13      8481                        Pale Lager      TomDecapolis
# 14      8481                        Pale Lager            hopdog
# 15      3228               Imperial/Double IPA           JJClark
# 16      3228               Imperial/Double IPA     CaptainCougar
# 17      3228               Imperial/Double IPA             StFun
# 18      3228               Imperial/Double IPA             MI2CA
# 19      3228               Imperial/Double IPA             vyvvy
#
#     review_appearance  review_aroma  review_palate  review_taste  \
# 0                   4             6              3             6
# 1                   4             6              4             7
# 2                   4             5              3             6
# 3                   2             4              2             4
# 4                   2             4              2             4
# 5                   5             8              4             7
# 6                   4             5              3             6
# 7                   2             6              3             7
# 8                   4             8              3             7
# 9                   3             8              4             8
# 10                  4             4              2             5
# 11                  3             5              3             7
# 12                  4             5              4             7
# 13                  3             6              3             6
# 14                  3             5              2             5
# 15                  4             8              4             8
# 16                  4             8              4             8
# 17                  3             7              3             6
# 18                  4             5              4             4
# 19                  3             6              3             6
#
#     review_overall                                        review_text  \
# 0               13   On tap at the Springfield, PA location. Poure...
# 1               13   On tap at the John Harvards in Springfield PA...
# 2               14   UPDATED: FEB 19, 2003 Springfield, PA. I've n...
# 3                8   On tap the Springfield PA location billed as ...
# 4                8   On tap at the Springfield, PA location. Poure...
# 5               16   Springfield, PA location... Poured an opaque ...
# 6               12   On tap at the Springfield, PA location. Liste...
# 7               14   Sampled @ the Springfield, PA location.   Can...
# 8               16   Springfield... Poured a hazy copper color wit...
# 9               17   UPDATED: FEB 19, 2003 Springfield, PA. Darkis...
# 10              11   UPDATED: FEB 19, 2003 Springfield, PA. Sharp ...
# 11              14   UPDATED: FEB 19, 2003 Springfield, PA. Intere...
# 12              14   From Springfield PA:  nice smooth\tmalty flav...
# 13              12   On tap at Springfield location.  Pours a tran...
# 14               9   On tap at the Springfield, PA location. Poure...
# 15              15   Handbottled from trade wth Sprinkle. Pours a ...
# 16              15   On tap at the Great Taste of the Midwest (8/9...
# 17              14   UPDATED: JUL 7, 2009 On tap. Interesting expe...
# 18              13   On cask at BI - Aroma of the Hopula Play-Doh ...
# 19              12   GTMW 08 on cask - Pours bronze orang with a m...
#
#     review_unix_time
# 0         1157587200
# 1         1157241600
# 2          958694400
# 3         1157587200
# 4         1157587200
# 5         1077753600
# 6         1176076800
# 7         1107302400
# 8         1102896000
# 9          996105600
# 10         958694400
# 11         958694400
# 12         990576000
# 13        1157587200
# 14        1157587200
# 15        1249257600
# 16        1245283200
# 17        1232841600
# 18        1222646400
# 19        1219536000

# %% [markdown]
# We get day of the week, month and day of year. Not sure if day of year will help but approximately measeures days after christmas. Keeping it in for now on the chance it might be usefull.
#
# I used US Central time zone to calculate these as most of the reviews are from the states.

# %%
from datetime import datetime
from pytz import timezone
import pytz

central = timezone('US/Central')

df['weekday_central'] =  df['review_unix_time'].apply(lambda x: 
                             pytz.utc.localize(datetime.utcfromtimestamp(x)).astimezone(central).strftime("%A"))


df['day_of_year'] =  df['review_unix_time'].apply(lambda x: 
                             pytz.utc.localize(datetime.utcfromtimestamp(x)).astimezone(central).timetuple().tm_yday)


df['month'] =  df['review_unix_time'].apply(lambda x: 
                             pytz.utc.localize(datetime.utcfromtimestamp(x)).astimezone(central).strftime("%m"))

# %%
test = timezone('US/Central')
pytz.utc.localize(datetime.utcfromtimestamp(958694400)).astimezone(test).strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2000-05-18 19:00:00'

# %%
# We use distance in months from July as a measure of the temperature/season
df['distance_from_july'] = df['month'].apply(lambda x: abs(7-int(x)))

# %%
# In a typical prouction situation, you would be making predictions based on past data so we 
# create train and test sets by splitting on a date. All test data is after that date

# I have used 10% of data as test data. As we'll see later, the training set needs to be split
# again so I want it to be fairly large

# %%
sorted_df=df.sort_values(by='review_unix_time')

# %%
df.count()
# Out:
# beerID                2924163
# beer_name             2924163
# abv                   2924163
# abv_listed            2924163
# brewerID              2924163
# beer_style            2924163
# reviewer_username     2924163
# review_appearance     2924163
# review_aroma          2924163
# review_palate         2924163
# review_taste          2924163
# review_overall        2924163
# review_text           2924163
# review_unix_time      2924163
# weekday_central       2924163
# day_of_year           2924163
# month                 2924163
# distance_from_july    2924163
# dtype: int64

# %%
2924163*0.9
# Out:
# 2631746.7

# %%
train_df, test_df = np.split(sorted_df, [2631746])

# %%
train_df.count()
# Out:
# beerID                2631746
# beer_name             2631746
# abv                   2631746
# abv_listed            2631746
# brewerID              2631746
# beer_style            2631746
# reviewer_username     2631746
# review_appearance     2631746
# review_aroma          2631746
# review_palate         2631746
# review_taste          2631746
# review_overall        2631746
# review_text           2631746
# review_unix_time      2631746
# weekday_central       2631746
# day_of_year           2631746
# month                 2631746
# distance_from_july    2631746
# dtype: int64

# %%
test_df.count()
# Out:
# beerID                292417
# beer_name             292417
# abv                   292417
# abv_listed            292417
# brewerID              292417
# beer_style            292417
# reviewer_username     292417
# review_appearance     292417
# review_aroma          292417
# review_palate         292417
# review_taste          292417
# review_overall        292417
# review_text           292417
# review_unix_time      292417
# weekday_central       292417
# day_of_year           292417
# month                 292417
# distance_from_july    292417
# dtype: int64

# %%
train_df.head()
# Out:
#          beerID                  beer_name  abv  abv_listed  brewerID  \
# 2291588     121      Stone City Hefeweizen  6.0       False        23
# 1651460     132        Newcastle Brown Ale  4.7        True       751
# 2146614     286   Worthington White Shield  5.6        True     12871
# 2182000     544           Saranac Pale Ale  5.5        True        92
# 2171356     547      Saranac Black and Tan  5.1        True        92
#
#                   beer_style reviewer_username  review_appearance  \
# 2291588    German Hefeweizen         lazarus99                  5
# 1651460            Brown Ale             billb                  5
# 2146614   Premium Bitter/ESB              wade                  3
# 2182000     English Pale Ale             billb                  4
# 2171356                Stout             billb                  3
#
#          review_aroma  review_palate  review_taste  review_overall  \
# 2291588             8              4            10              20
# 1651460             6              5             9              17
# 2146614            10              4             9              18
# 2182000             7              5             9              17
# 2171356             7              2             6              10
#
#                                                review_text  review_unix_time  \
# 2291588   I love this kind of beer. It seems to be the ...         955497600
# 1651460   This has to be one of my favorite drinking be...         955497600
# 2146614   Excellent ale with a strong aroma and initial...         955843200
# 2182000   Pretty tasty for a pale ale.  This is one of ...         956448000
# 2171356   I a big fan of Black and Tans but this one is...         956448000
#
#         weekday_central  day_of_year month  distance_from_july
# 2291588         Tuesday          102    04                   3
# 1651460         Tuesday          102    04                   3
# 2146614        Saturday          106    04                   3
# 2182000        Saturday          113    04                   3
# 2171356        Saturday          113    04                   3

# %%
test_df.head()
# Out:
#          beerID                         beer_name  abv  abv_listed  brewerID  \
# 2081618  136550             Lost Abbey Sinners 10  8.0        True      7043
# 1729409   23373   Brewbakers Surf City Blonde Ale  6.0       False       390
# 2281210   48725      Port Washington Hop-2-It IPA  6.0        True      1336
# 1122846  101199                   Founders Cerise  6.5        True       554
# 1238760  145953             Muirhouse Magnum Mild  4.5        True     11110
#
#                             beer_style reviewer_username  review_appearance  \
# 2081618              Sour Ale/Wild Ale          MrChopin                  2
# 1729409           Golden Ale/Blond Ale         bartalone                  3
# 2281210   India Pale Ale &#40;IPA&#41;        nuplastikk                  3
# 1122846                     Fruit Beer      hoosiers1994                  4
# 1238760                       Mild Ale             maeib                  4
#
#          review_aroma  review_palate  review_taste  review_overall  \
# 2081618             5              2             6               9
# 1729409             3              2             5               7
# 2281210             7              3             7              14
# 1122846             6              3             6              11
# 1238760             8              3             7              15
#
#                                                review_text  review_unix_time  \
# 2081618   Bottle opens with the sound of repressed fart...        1306713600
# 1729409   Not a strong flavor  mild, very very mild  mu...        1306713600
# 2281210   Sample at Hops Haven.  Hazy orange tan.  Thin...        1306713600
# 1122846   12 oz bottle poured into a tulip.  Aroma of b...        1306713600
# 1238760   Cask conditioned\tgravity dispense\tNorthants...        1306713600
#
#         weekday_central  day_of_year month  distance_from_july
# 2081618          Sunday          149    05                   2
# 1729409          Sunday          149    05                   2
# 2281210          Sunday          149    05                   2
# 1122846          Sunday          149    05                   2
# 1238760          Sunday          149    05                   2

# %%
train_df.to_pickle(path='./train_set.pkl')

# %%
test_df.to_pickle(path='./test_set.pkl')
